# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 2: Mining Facebook: Analyzing Fan Pages, Examining Friendships, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Facebook API Access
#
# Facebook implements OAuth 2.0 as its standard authentication mechanism, but provides a convenient way for you to get an _access token_ for development purposes, and we'll opt to take advantage of that convenience in this notebook. For details on implementing an OAuth flow with Facebook (all from within IPython Notebook), see the \_AppendixB notebook from the [IPython Notebook Dashboard](/).
#
# For this first example, login to your Facebook account and go to https://developers.facebook.com/tools/explorer/ to obtain and set permissions for an access token that you will need to define in the code cell defining the ACCESS_TOKEN variable below.
#
# Be sure to explore the permissions that are available by clicking on the "Get Access Token" button that's on the page and exploring all of the tabs available. For example, you will need to set the "friends_likes" option under the "Friends Data Permissions" since this permission is used by the script below but is not a basic permission and is not enabled by default.
#
# <img src="files/resources/ch02-facebook/images/FB_GraphExplorer_perms.png" width="300px" /><br />

# %%
# Copy and paste in the value you just got from the inline frame into this variable and execute this cell.
# Keep in mind that you could have just gone to https://developers.facebook.com/tools/access_token/
# and retrieved the "User Token" value from the Access Token Tool
# %pylab inline
#!/usr/bin/env python
# -*- coding: utf-8 -*-


ACCESS_TOKEN = 'CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Example 1. Making Graph API requests over HTTP

# %%
import requests # pip install requests
import json

base_url = 'https://graph.facebook.com/me'

# Get 10 likes for 10 friends
fields = 'id,name,likes,friends.limit(10).fields(likes.limit(10))'

url = '%s?fields=%s&access_token=%s' % \
    (base_url, fields, ACCESS_TOKEN,)

# This API is HTTP-based and could be requested in the browser,
# with a command line utlity like curl, or using just about
# any programming language by making a request to the URL.
# Click the hyperlink that appears in your notebook output
# when you execute this code cell to see for yourself...
print (url)

# Interpret the response as JSON and convert back
# to Python data structures
content = requests.get(url).json()

# Pretty-print the JSON and display it
print (json.dumps(content, indent=2))
# Out:
# https://graph.facebook.com/me?fields=id,name,likes,friends.limit(10).fields(likes.limit(10))&access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD
# {
#   "friends": {
#     "data": [],
#     "summary": {
#       "total_count": 83
#     }
#   },
#   "id": "10203145752473658",
#   "name": "Liu Bin",
#   "likes": {
#     "paging": {
#       "cursors": {
#         "after": "MTcwNjA4MTA5NjQ1NTQy",
#         "before": "MjU4MDQ3NDk3NjE1NDg5"
#       },
#       "next": "https://graph.facebook.com/v2.0/10203145752473658/likes?access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD&limit=25&after=MTcwNjA4MTA5NjQ1NTQy"
#     },
#     "data": [
#       {
#         "created_time": "2015-12-14T22:45:20+0000",
#         "id": "258047497615489",
#         "category": "Athlete",
#         "name": "Narmin Assria IFBB Bikini Pro"
#       },
#       {
#         "created_time": "2015-12-14T22:45:10+0000",
#         "id": "124500284255091",
#         "category": "Athlete",
#         "name": "Felice Herrig fan page"
#       },
#       {
#         "created_time": "2015-06-21T19:25:46+0000",
#         "id": "556264724526931",
#         "category": "Community",
#         "name": "Cung Ho\u00e0ng \u0110\u1ea1o"
#       },
#       {
#         "created_time": "2014-12-10T16:01:39+0000",
#         "id": "239209922765678",
#         "category": "Athlete",
#         "name": "Christina Vargas"
#       },
#       {
#         "created_time": "2014-11-19T18:39:36+0000",
#         "id": "147170835314482",
#         "category": "Public Figure",
#         "name": "Emily Skye"
#       },
#       {
#         "created_time": "2014-11-18T12:42:25+0000",
#         "id": "449997995096836",
#         "category": "Entertainer",
#         "name": "CLARA"
#       },
#       {
#         "created_time": "2014-11-18T12:41:40+0000",
#         "id": "288596241260375",
#         "category": "Athlete",
#         "name": "Paige Hathaway"
#       },
#       {
#         "created_time": "2014-11-18T00:13:37+0000",
#         "id": "181712638644349",
#         "category": "Software",
#         "name": "The Xen Project"
#       },
#       {
#         "created_time": "2014-10-28T08:45:29+0000",
#         "id": "187030591324147",
#         "category": "Product/Service",
#         "name": "TurnKey GNU/Linux"
#       },
#       {
#         "created_time": "2014-10-24T03:29:59+0000",
#         "id": "406433779383",
#         "category": "Entertainer",
#         "name": "Dwayne The Rock Johnson"
#       },
#       {
#         "created_time": "2014-08-26T01:54:25+0000",
#         "id": "67920382572",
#         "category": "Sports Team",
#         "name": "Liverpool FC"
#       },
#       {
#         "created_time": "2014-08-26T01:54:21+0000",
#         "id": "19034719952",
#         "category": "Sports Team",
#         "name": "Real Madrid C.F."
#       },
#       {
#         "created_time": "2014-08-26T01:54:18+0000",
#         "id": "197394889304",
#         "category": "Sports Team",
#         "name": "FC Barcelona"
#       },
#       {
#         "created_time": "2014-08-26T01:54:10+0000",
#         "id": "7724542745",
#         "category": "Sports Team",
#         "name": "Manchester United"
#       },
#       {
#         "created_time": "2014-08-26T01:51:41+0000",
#         "id": "5565627823",
#         "category": "Musician/Band",
#         "name": "Christina Aguilera"
#       },
#       {
#         "created_time": "2014-08-26T01:51:13+0000",
#         "id": "28940545600",
#         "category": "Musician/Band",
#         "name": "Beyonc\u00e9"
#       },
#       {
#         "created_time": "2014-08-26T01:51:00+0000",
#         "id": "112525015425778",
#         "category": "Musician/Band",
#         "name": "Paul McCartney"
#       },
#       {
#         "created_time": "2014-08-26T01:50:51+0000",
#         "id": "8210451787",
#         "category": "Musician/Band",
#         "name": "Linkin Park"
#       },
#       {
#         "created_time": "2014-08-26T01:50:44+0000",
#         "id": "5413509299",
#         "category": "Musician/Band",
#         "name": "Avril Lavigne"
#       },
#       {
#         "created_time": "2014-08-26T01:50:36+0000",
#         "id": "19691681472",
#         "category": "Musician/Band",
#         "name": "Michael Jackson"
#       },
#       {
#         "created_time": "2014-08-26T01:50:33+0000",
#         "id": "67253243887",
#         "category": "Musician/Band",
#         "name": "Justin Bieber"
#       },
#       {
#         "created_time": "2014-08-26T01:50:32+0000",
#         "id": "45309870078",
#         "category": "Musician/Band",
#         "name": "Eminem"
#       },
#       {
#         "created_time": "2012-02-14T00:07:37+0000",
#         "id": "131479102555",
#         "category": "Software",
#         "name": "OpenNebula"
#       },
#       {
#         "created_time": "2011-08-26T00:38:56+0000",
#         "id": "181876955215025",
#         "category": "Personal Blog",
#         "name": "Steve Jobs & The Sound of Silence"
#       },
#       {
#         "created_time": "2011-08-23T10:14:34+0000",
#         "id": "170608109645542",
#         "category": "Company",
#         "name": "findertrip.com",
#         "category_list": [
#           {
#             "id": "2200",
#             "name": "Company"
#           }
#         ]
#       }
#     ]
#   }
# }

# %% [markdown]
# Note: If you attempt to run a query for all of your friends' likes and it appears to hang, it is probably because you have a lot of friends who have a lot of likes. If this happens, you may need to add limits and offsets to the fields in the query as described in Facebook's [field expansion](https://developers.facebook.com/docs/reference/api/field_expansion/) documentation. However, the <code>facebook</code> library that we'll use in the next example handles some of these issues, so it's recommended that you hold off and try it out first. This initial example is just to illustrate that Facebook's API is built on top of HTTP.
#
# A couple of field limit/offset examples that illustrate the possibilities follow:
#
# <code>
# fields = 'id,name,friends.limit(10).fields(likes)'            # Get all likes for 10 friends
# fields = 'id,name,friends.offset(10).limit(10).fields(likes)' # Get all likes for 10 more friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# fields = 'id,name,friends.fields(likes.limit(10))'            # Get 10 likes for all friends
# </code>

# %% [markdown]
# ## Example 2. Querying the Graph API with Python

# %%
import facebook # pip install facebook-sdk
import json

# A helper function to pretty-print Python objects as JSON

def pp(o): 
    print (json.dumps(o, indent=1))

# Create a connection to the Graph API with your access token

g = facebook.GraphAPI(ACCESS_TOKEN)

# Execute a few sample queries

print ('---------------')
print ('Me')
print ('---------------')
pp(g.get_object('me'))
print ('---------------')
print ('My Friends')
print ('---------------')
pp(g.get_connections('me', 'friends'))
print ('---------------')
print ('Social Web')
print ('---------------')
pp(g.request("search", {'q' : 'social web', 'type' : 'page'}))
# Out:
# ---------------
# Me
# ---------------
# {
#  "education": [
#   {
#    "type": "High School",
#    "year": {
#     "id": "144503378895008",
#     "name": "1999"
#    },
#    "school": {
#     "id": "117532448279486",
#     "name": "\u8425\u53e3\u5e02\u9ad8\u7ea7\u4e2d\u5b66"
#    }
#   },
#   {
#    "type": "College",
#    "year": {
#     "id": "140617569303679",
#     "name": "2007"
#    },
#    "school": {
#     "id": "108341885853763",
#     "name": "Beijing Institute of Technology"
#    }
#   }
#  ],
#  "location": {
#   "id": "110730292284790",
#   "name": "Beijing, China"
#  },
#  "name": "Liu Bin",
#  "gender": "male",
#  "bio": "Librarian Programmer",
#  "first_name": "Bin",
#  "updated_time": "2015-06-06T05:30:02+0000",
#  "link": "https://www.facebook.com/app_scoped_user_id/10203145752473658/",
#  "last_name": "Liu",
#  "verified": true,
#  "birthday": "08/16/1983",
#  "timezone": 8,
#  "favorite_athletes": [
#   {
#    "id": "258047497615489",
#    "name": "Narmin Assria IFBB Bikini Pro"
#   },
#   {
#    "id": "124500284255091",
#    "name": "Felice Herrig fan page"
#   },
#   {
#    "id": "239209922765678",
#    "name": "Christina Vargas"
#   },
#   {
#    "id": "288596241260375",
#    "name": "Paige Hathaway"
#   }
#  ],
#  "relationship_status": "Divorced",
#  "hometown": {
#   "id": "109396549078767",
#   "name": "Yingkou"
#  },
#  "favorite_teams": [
#   {
#    "id": "67920382572",
#    "name": "Liverpool FC"
#   },
#   {
#    "id": "19034719952",
#    "name": "Real Madrid C.F."
#   },
#   {
#    "id": "197394889304",
#    "name": "FC Barcelona"
#   },
#   {
#    "id": "7724542745",
#    "name": "Manchester United"
#   }
#  ],
#  "work": [
#   {
#    "employer": {
#     "id": "103767179661771",
#     "name": "Beijing International Studies University"
#    }
#   }
#  ],
#  "interested_in": [
#   "male"
#  ],
#  "email": "liu1983bin@gmail.com",
#  "locale": "zh_CN",
#  "id": "10203145752473658",
#  "languages": [
#   {
#    "id": "111735208843636",
#    "name": "Chinese"
#   },
#   {
#    "id": "113301478683221",
#    "name": "American English"
#   }
#  ]
# }
# ---------------
# My Friends
# ---------------
# {
#  "data": [],
#  "summary": {
#   "total_count": 83
#  }
# }
# ---------------
# Social Web
# ---------------
# {
#  "paging": {
#   "cursors": {
#    "after": "NTA4",
#    "before": "MAZDZD"
#   }
#  },
#  "data": [
#   {
#    "id": "105830116116453",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Sherpas",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "226633110719998",
#    "category": "Consulting/Business Services",
#    "name": "SocialWebMarketing",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "515092701968229",
#    "category": "Business Services",
#    "name": "LS Social Web",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "205510939478893",
#      "name": "Copying & Printing"
#     }
#    ]
#   },
#   {
#    "id": "162257397196866",
#    "category": "Education",
#    "name": "ITE College West - Nitec in Social Media and Web Development",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ]
#   },
#   {
#    "id": "144307838980365",
#    "category": "Consulting/Business Services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "114355558650055",
#    "category": "Business Services",
#    "name": "socialWEB",
#    "category_list": [
#     {
#      "id": "200209719995975",
#      "name": "Business Supply Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "172427156148334",
#    "category": "Internet/Software",
#    "name": "Social & Web Marketing",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "112879218725926",
#    "category": "Interest",
#    "name": "Social web"
#   },
#   {
#    "id": "122698737762622",
#    "category": "Local Business",
#    "name": "Social Web Dzine",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "479064558889277",
#    "category": "Local Business",
#    "name": "Social Web Design",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ]
#   },
#   {
#    "id": "210125749066257",
#    "category": "Product/Service",
#    "name": "The Social Webb"
#   },
#   {
#    "id": "454206868103318",
#    "category": "App Page",
#    "name": "WebSocial"
#   },
#   {
#    "id": "160477007390933",
#    "category": "Internet/Software",
#    "name": "Social Web Alliance"
#   },
#   {
#    "id": "156397537717282",
#    "category": "Local Business",
#    "name": "Websix Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "833575423359366",
#    "category": "Arts/Humanities Website",
#    "name": "Social Web Art"
#   },
#   {
#    "id": "162973743866087",
#    "category": "Small Business",
#    "name": "Social Web Tactics",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "76277666156",
#    "category": "Computers/Internet Website",
#    "name": "My Social Web"
#   },
#   {
#    "id": "327997047315600",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Associates",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "712032982208651",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Communication"
#   },
#   {
#    "id": "146803958708175",
#    "category": "Book",
#    "name": "Mining the Social Web"
#   },
#   {
#    "id": "1201605436523723",
#    "category": "Internet/Software",
#    "name": "Social WEB Service",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "178669642178193",
#      "name": "Social Services"
#     }
#    ]
#   },
#   {
#    "id": "367809806695037",
#    "category": "Software",
#    "name": "Social Webshop UK"
#   },
#   {
#    "id": "103944626326539",
#    "category": "Local Business",
#    "name": "Social Web Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ]
#   },
#   {
#    "id": "162028037196792",
#    "category": "Local Business",
#    "name": "Social Web Innovation"
#   },
#   {
#    "id": "145640058839737",
#    "category": "Internet/Software",
#    "name": "Red Social Per\u00fa - Aplicaciones Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "119307778101744",
#    "category": "Local Business",
#    "name": "Web1 Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ]
#   },
#   {
#    "id": "198566960212311",
#    "category": "Interest",
#    "name": "Social website"
#   },
#   {
#    "id": "330043283780",
#    "category": "Internet/Software",
#    "name": "Social web design by x10industries",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "145218172174013",
#    "category": "Professional Services",
#    "name": "Social Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "145691832245728",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Manager",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "125310277520246",
#    "category": "Professional Services",
#    "name": "Web in Fermento - Marketing nel Social Web e NewMedia Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "255596497809113",
#    "category": "Product/Service",
#    "name": "Social Web Cafe"
#   },
#   {
#    "id": "185753574790507",
#    "category": "Computers/Internet Website",
#    "name": "SocialWeb.ro"
#   },
#   {
#    "id": "8387137434",
#    "category": "Local Business",
#    "name": "Social Web Strategies",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ]
#   },
#   {
#    "id": "472621429448414",
#    "category": "Small Business",
#    "name": "Oferplay Desarrollo Web y Social Media",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "208290102524008",
#    "category": "Consulting/Business Services",
#    "name": "WebSocial"
#   },
#   {
#    "id": "1608481909401292",
#    "category": "Consulting/Business Services",
#    "name": "Mosaic Web Solutions- Best Social Media and SEO Marketing Philippines",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "139004380018",
#    "category": "Local Business",
#    "name": "MerlinFX Web Email Marketing Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ]
#   },
#   {
#    "id": "107894379351327",
#    "category": "Internet/Software",
#    "name": "22Social",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "104235069630517",
#    "category": "Consulting/Business Services",
#    "name": "Barclay Jones - Recruitment Technology and Social Media",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ]
#   },
#   {
#    "id": "290533004485031",
#    "category": "Media/News/Publishing",
#    "name": "Social Savvy Co - Web Design and Social Media Management",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ]
#   },
#   {
#    "id": "375690975214",
#    "category": "Non-Profit Organization",
#    "name": "Radio Social Web",
#    "category_list": [
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ]
#   },
#   {
#    "id": "103989939638996",
#    "category": "Interest",
#    "name": "Social Semantic Web"
#   },
#   {
#    "id": "295703510589892",
#    "category": "Community",
#    "name": "Social WEB"
#   },
#   {
#    "id": "657099161012700",
#    "category": "Business Services",
#    "name": "Social Web Promoter",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "1425389227704470",
#    "category": "Website",
#    "name": "Social Web Girl"
#   },
#   {
#    "id": "453109534836350",
#    "category": "Consulting/Business Services",
#    "name": "Web & Wissen - Social Media-Beratung und Onlineredaktion",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "147895125402338",
#    "category": "Internet/Software",
#    "name": "Life Social Web",
#    "category_list": [
#     {
#      "id": "108470879231339",
#      "name": "Research Service"
#     },
#     {
#      "id": "192119584190796",
#      "name": "Event"
#     }
#    ]
#   },
#   {
#    "id": "636570933034875",
#    "category": "Community Organization",
#    "name": "SocialWebConneXion.com",
#    "category_list": [
#     {
#      "id": "152880021441864",
#      "name": "Community Organization"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     }
#    ]
#   },
#   {
#    "id": "111063838916102",
#    "category": "Interest",
#    "name": "List of social networking websites"
#   },
#   {
#    "id": "133517650020227",
#    "category": "Interest",
#    "name": "Social Web Academy"
#   },
#   {
#    "id": "190124415513",
#    "category": "Internet/Software",
#    "name": "Grafdom - Web Design & Social Media",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "142810595790974",
#    "category": "Media/News/Publishing",
#    "name": "Social Web Strategy",
#    "category_list": [
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     },
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     }
#    ]
#   },
#   {
#    "id": "681921881866837",
#    "category": "Consulting/Business Services",
#    "name": "Whitedrop  Web Marketing Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "339474376250286",
#    "category": "Computers/Technology",
#    "name": "Himbaface social web application"
#   },
#   {
#    "id": "174735529355893",
#    "category": "Internet/Software",
#    "name": "Social Webs"
#   },
#   {
#    "id": "214631441934914",
#    "category": "Consulting/Business Services",
#    "name": "Web.Search.Social"
#   },
#   {
#    "id": "298574890156815",
#    "category": "Education",
#    "name": "Social Media e Web Community Manager Make it So",
#    "category_list": [
#     {
#      "id": "186998168001766",
#      "name": "Private School"
#     }
#    ]
#   },
#   {
#    "id": "423015291215477",
#    "category": "Consulting/Business Services",
#    "name": "Webtures Social",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "1378760945677870",
#    "category": "Internet/Software",
#    "name": "Web Labs - Social Media Team",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "1574818702754538",
#    "category": "Professional Services",
#    "name": "Social Web Agency",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "131570646875176",
#    "category": "Local Business",
#    "name": "Dot Ingenuity Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "187494864706626",
#    "category": "Consulting/Business Services",
#    "name": "Social Bee Web Marketing and Design"
#   },
#   {
#    "id": "598817503529463",
#    "category": "App Page",
#    "name": "Social Web Reporter"
#   },
#   {
#    "id": "589464101164823",
#    "category": "Community",
#    "name": "SocialWeb"
#   },
#   {
#    "id": "1479726435651428",
#    "category": "Company",
#    "name": "SocialWeb"
#   },
#   {
#    "id": "290608457641244",
#    "category": "Society/Culture Website",
#    "name": "SOCIAL WEBSITE"
#   },
#   {
#    "id": "136481676384923",
#    "category": "Consulting/Business Services",
#    "name": "Leading Logic - Web, Social, Marketing, Design",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "292125494205150",
#    "category": "Professional Services",
#    "name": "Local Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "741224886007858",
#    "category": "Local Business",
#    "name": "Websites R Us",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "444124702299250",
#    "category": "Consulting/Business Services",
#    "name": "WebSocial Business Solutions"
#   },
#   {
#    "id": "1614374688834029",
#    "category": "Internet/Software",
#    "name": "Velocity SEO - Web Design - Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "1511437179114307",
#    "category": "Media/News/Publishing",
#    "name": "Social Web Arena"
#   },
#   {
#    "id": "179635912063410",
#    "category": "Local Business",
#    "name": "Web Social Marketing Firenze",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "138187269563360",
#    "category": "Entertainment Website",
#    "name": "Social-Webcam"
#   },
#   {
#    "id": "153169621372946",
#    "category": "Company",
#    "name": "Internet-Rhetorik - Kommunikation im Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "317767175055524",
#    "category": "Internet/Software",
#    "name": "WEB Promotion Agency Italia - Siti Web e Social Network - Pubblicit\u00e0 Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "1718799715005821",
#    "category": "Business Services",
#    "name": "Es Social Web",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "1650412518536159",
#    "category": "Business Services",
#    "name": "Social Web News",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "1410567895848855",
#    "category": "Internet/Software",
#    "name": "FUA Social Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "123000931064408",
#    "category": "Internet/Software",
#    "name": "Optragroup - Agence Web & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "161811347201528",
#      "name": "Lodging"
#     }
#    ]
#   },
#   {
#    "id": "223239324395549",
#    "category": "Internet/Software",
#    "name": "bluehouse - Die Web & Social Media Agentur",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "519084648117730",
#    "category": "Local Business",
#    "name": "Ed Doherty Jr. - SEO, Social, Web Design"
#   },
#   {
#    "id": "1438118799768086",
#    "category": "Consulting/Business Services",
#    "name": "Social Webwork"
#   },
#   {
#    "id": "488323237847526",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Gym",
#    "category_list": [
#     {
#      "id": "185900881450649",
#      "name": "Personal Coaching"
#     }
#    ]
#   },
#   {
#    "id": "46316179114",
#    "category": "Internet/Software",
#    "name": "Artwhere Mobile Social Web",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "1398644970370772",
#    "category": "Community",
#    "name": "Web COmmunities for Statistics for Social Innovation"
#   },
#   {
#    "id": "210604392401626",
#    "category": "Internet/Software",
#    "name": "Social Website"
#   },
#   {
#    "id": "114874051893438",
#    "category": "Company",
#    "name": "Social Web Thing"
#   },
#   {
#    "id": "536447329843713",
#    "category": "Consulting/Business Services",
#    "name": "Social WebNet LLC"
#   },
#   {
#    "id": "226795074081704",
#    "category": "Media/News/Publishing",
#    "name": "TAG - Social Web Radio",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "691387304273877",
#    "category": "Professional Services",
#    "name": "ISocial Web",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "216734806323",
#    "category": "Company",
#    "name": "More Cabbage Social PR, Branding, & Websites",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "125248858533",
#    "category": "Local Business",
#    "name": "Social Media Web Development",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "1394913830760636",
#    "category": "Website",
#    "name": "Social Webshop"
#   },
#   {
#    "id": "179814955402116",
#    "category": "Professional Services",
#    "name": "Studio Castelli - Comunicazione, grafica, web, social strategies",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "227273367442760",
#    "category": "Computers/Technology",
#    "name": "Social webs cheats"
#   },
#   {
#    "id": "323337601029865",
#    "category": "Consulting/Business Services",
#    "name": "Mobile Social Web Consulting"
#   },
#   {
#    "id": "645332448912697",
#    "category": "Computers/Technology",
#    "name": "Websites and Social Media Pty Ltd",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "153823274652343",
#    "category": "Media/News/Publishing",
#    "name": "RK Image :: Video, Web, Photo, Social Media"
#   },
#   {
#    "id": "185786224537",
#    "category": "Professional Services",
#    "name": "LightHouse Graphics - Web, SEO and Social Media",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "101879543513",
#    "category": "Professional Services",
#    "name": "Multimediavda.com web & social media agency Aosta",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     }
#    ]
#   },
#   {
#    "id": "114016465440871",
#    "category": "Community",
#    "name": "Social Web Platform"
#   },
#   {
#    "id": "199019100182074",
#    "category": "Consulting/Business Services",
#    "name": "Presto Web Design & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "155558871132308",
#    "category": "Internet/Software",
#    "name": "Ask Rosalie -  Website & Social Media Help Desk",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "470852336273104",
#    "category": "Business Services",
#    "name": "Social Web Ranking",
#    "category_list": [
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "144654462241199",
#    "category": "Small Business",
#    "name": "glenroyDAVIE Signs | Web | Social Media | Print",
#    "category_list": [
#     {
#      "id": "2237",
#      "name": "Small Business"
#     }
#    ]
#   },
#   {
#    "id": "100306133360993",
#    "category": "Professional Services",
#    "name": "RedHot Design | Web Designers + Social Media Strategists",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "45366739923",
#    "category": "Local Business",
#    "name": "PC Designs UK - Web & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "577684822294787",
#    "category": "Professional Services",
#    "name": "Web & Social Solutions - Siti Internet, SEO, Social Networks e Formazione",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "1643849105875146",
#    "category": "Professional Services",
#    "name": "Dhyana Web and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ]
#   },
#   {
#    "id": "101777593502934",
#    "category": "Internet/Software",
#    "name": "Social Web Solutions"
#   },
#   {
#    "id": "885851341468862",
#    "category": "Local Business",
#    "name": "Agenzia Tesoro - Social & Web",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "201528873201605",
#      "name": "Management Service"
#     }
#    ]
#   },
#   {
#    "id": "464943686887751",
#    "category": "Professional Services",
#    "name": "SWM - Social Web Management",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "125283660816381",
#    "category": "Consulting/Business Services",
#    "name": "Kloud Social - SEO, SMO & Web Dev"
#   },
#   {
#    "id": "403059893050740",
#    "category": "Internet/Software",
#    "name": "Social Web Tools"
#   },
#   {
#    "id": "169424813098860",
#    "category": "Local Business",
#    "name": "LocalizerUK - Online Marketing, Social Media and Mobile Web Services",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ]
#   },
#   {
#    "id": "502559819771053",
#    "category": "Company",
#    "name": "Webshoutz be social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "760512814009739",
#    "category": "Internet/Software",
#    "name": "Web Design & Social Media Solution",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "1703925146552148",
#    "category": "Computers/Technology",
#    "name": "Social WebMarketing France"
#   },
#   {
#    "id": "105478339515932",
#    "category": "Local Business",
#    "name": "SocialExecs | Social Media & Web Specialists"
#   },
#   {
#    "id": "193455924323226",
#    "category": "Computers/Internet Website",
#    "name": "Web Social Puglia"
#   },
#   {
#    "id": "185366164983180",
#    "category": "Internet/Software",
#    "name": "Bonobo - Web & Social Media"
#   },
#   {
#    "id": "137058369654806",
#    "category": "Community",
#    "name": "Keine Kinderfotos im Social Web"
#   },
#   {
#    "id": "339797189378903",
#    "category": "Internet/Software",
#    "name": "Fletcher Web Marketing | SEO | SEM | Social Media | Analytics"
#   },
#   {
#    "id": "290193207726357",
#    "category": "Education",
#    "name": "The Social Mobile WEB Business Conference",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ]
#   },
#   {
#    "id": "195822857133037",
#    "category": "Consulting/Business Services",
#    "name": "Chaser Media - Social Media, Web Design and Photography Services"
#   },
#   {
#    "id": "104917969542058",
#    "category": "Education",
#    "name": "Social Media Marketing & Web Communication - Executive Master SDC IULM",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     }
#    ]
#   },
#   {
#    "id": "1051371338208108",
#    "category": "Local Business",
#    "name": "Whitby Web Design And Social Media Advertising",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "192541364117143",
#    "category": "Education",
#    "name": "WebSocial",
#    "category_list": [
#     {
#      "id": "151676848220295",
#      "name": "Education"
#     },
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "194215723940053",
#    "category": "Community",
#    "name": "Social Web Graphics"
#   },
#   {
#    "id": "281836288662574",
#    "category": "Consulting/Business Services",
#    "name": "Digital Agenda  - Web Development and Social Media Services",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "686324361511474",
#    "category": "Company",
#    "name": "WEB Social Global"
#   },
#   {
#    "id": "426710170752907",
#    "category": "Media/News/Publishing",
#    "name": "Kreativevue Web Design & Social Media"
#   },
#   {
#    "id": "225944470853448",
#    "category": "Local Business",
#    "name": "So Crafty Social Media / Web Design / PR",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "169708609749841",
#    "category": "Professional Services",
#    "name": "WeBetter - Social & Marketing",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "233682666821223",
#    "category": "Internet/Software",
#    "name": "Web Social Dev"
#   },
#   {
#    "id": "171948265971",
#    "category": "Internet/Software",
#    "name": "Dise\u00f1o Web, Social Media e-mandinga",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "284744201616049",
#    "category": "Consulting/Business Services",
#    "name": "Webtye - Web, Mobile, Social & Search",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "358483060859947",
#      "name": "Startup"
#     }
#    ]
#   },
#   {
#    "id": "67783847861",
#    "category": "Product/Service",
#    "name": "Social Web Factory"
#   },
#   {
#    "id": "308128076037839",
#    "category": "Consulting/Business Services",
#    "name": "Web & Social Marketing",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "449187528446529",
#    "category": "Internet/Software",
#    "name": "Malekoo Web Development and Social Media Marketing"
#   },
#   {
#    "id": "400165133506829",
#    "category": "Internet/Software",
#    "name": "Web And Social Media Design",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "147467965376263",
#    "category": "Professional Services",
#    "name": "Lucas K. Williams: Engineering, Web, Tech and Social Media Marketing GURU",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "132214966858612",
#    "category": "Local Business",
#    "name": "eitbits Webs & Social Media"
#   },
#   {
#    "id": "128172607258182",
#    "category": "Internet/Software",
#    "name": "Social Webforce",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ]
#   },
#   {
#    "id": "1481733692135777",
#    "category": "Internet/Software",
#    "name": "SocialWeb Desenvolvimento"
#   },
#   {
#    "id": "488498934539529",
#    "category": "News/Media Website",
#    "name": "Web Marketing et Communication Social Media"
#   },
#   {
#    "id": "103438709711859",
#    "category": "Interest",
#    "name": "Use of social network websites in investigations"
#   },
#   {
#    "id": "316613681700247",
#    "category": "Computers/Internet Website",
#    "name": "Social Web Talks"
#   },
#   {
#    "id": "408492742542624",
#    "category": "Interest",
#    "name": "Webcam Social Shopper"
#   },
#   {
#    "id": "149583259175",
#    "category": "Education Website",
#    "name": "Social Web Learning"
#   },
#   {
#    "id": "132456623459954",
#    "category": "Local Business",
#    "name": "Web Savvy Social Media"
#   },
#   {
#    "id": "261688960613759",
#    "category": "Professional Services",
#    "name": "Impulsive Labs Web Design & Social Media Management",
#    "category_list": [
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "669751383086793",
#    "category": "Internet/Software",
#    "name": "SocialWeb",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "192046090848741",
#    "category": "Education",
#    "name": "Social Web Academy"
#   },
#   {
#    "id": "441220109348770",
#    "category": "Website",
#    "name": "Social Web"
#   },
#   {
#    "id": "1719333961614063",
#    "category": "Product/Service",
#    "name": "MyWeb Social"
#   },
#   {
#    "id": "445746788774576",
#    "category": "App Page",
#    "name": "Web Social Mania"
#   },
#   {
#    "id": "112879788755706",
#    "category": "Consulting/Business Services",
#    "name": "Webfluence Social Media & Internet Marketing",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "252633804884736",
#    "category": "Internet/Software",
#    "name": "Milano Social Web"
#   },
#   {
#    "id": "389545474484483",
#    "category": "Consulting/Business Services",
#    "name": "MySocialWeb.nl",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "176585309085606",
#    "category": "Interest",
#    "name": "Sweden Social Web Camp"
#   },
#   {
#    "id": "125953907477790",
#    "category": "Consulting/Business Services",
#    "name": "Social Media & Website Solutions by 108 degrees",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     }
#    ]
#   },
#   {
#    "id": "420596024795870",
#    "category": "Computers/Internet Website",
#    "name": "Riva Social Weblog"
#   },
#   {
#    "id": "200678389975863",
#    "category": "Consulting/Business Services",
#    "name": "Wellman Works, Ltd. - Internet Marketing, Social Media, and Web Design",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "175318852545291",
#    "category": "Website",
#    "name": "Social Web BREAKFAST"
#   },
#   {
#    "id": "117295595039817",
#    "category": "Internet/Software",
#    "name": "SkyNixWebdesign: Web Design and Social Media Management"
#   },
#   {
#    "id": "532009816944028",
#    "category": "Consulting/Business Services",
#    "name": "Mackey Digital - Web & Social Media Solutions",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "358524254168284",
#    "category": "Computers/Internet Website",
#    "name": "SocialWebOS"
#   },
#   {
#    "id": "156184496617",
#    "category": "Website",
#    "name": "Social Web"
#   },
#   {
#    "id": "120366748050821",
#    "category": "Community",
#    "name": "ITE College Central - Social Media & Web Development"
#   },
#   {
#    "id": "143631244740",
#    "category": "Local Business",
#    "name": "Global Vision Web &  Social Media Company",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "230470560302996",
#    "category": "Media/News/Publishing",
#    "name": "Social Webmarks"
#   },
#   {
#    "id": "658425767604330",
#    "category": "Consulting/Business Services",
#    "name": "Emma Fern\u00e1ndez \u00b7SEO \u00b7 Web \u00b7Social Media",
#    "category_list": [
#     {
#      "id": "108472109230615",
#      "name": "Computer Services"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     },
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "241356662574034",
#    "category": "Consulting/Business Services",
#    "name": "Business Marketing Company via Website Design, Social Networking and SEO",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "340506199316371",
#    "category": "Internet/Software",
#    "name": "TiWebDesign",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "102832526428160",
#    "category": "Local Business",
#    "name": "Social Media Management With RedFuel Web Design",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "124131750957589",
#    "category": "Small Business",
#    "name": "Ignite Social Web"
#   },
#   {
#    "id": "544735338886640",
#    "category": "Professional Services",
#    "name": "BT Designs - Web Design & Social Media"
#   },
#   {
#    "id": "117391341647335",
#    "category": "Internet/Software",
#    "name": "NetRight: Web Design and Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "36575011414",
#    "category": "Company",
#    "name": "Social Semantic Web"
#   },
#   {
#    "id": "1845522299007623",
#    "category": "Local Business",
#    "name": "DanSpalding.net - Web Digital Social Media and Design",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "150944928251073",
#    "category": "Local Business",
#    "name": "Social Media - \u039a\u03bf\u03b9\u03bd\u03c9\u03bd\u03b9\u03ba\u03ac \u0394\u03af\u03ba\u03c4\u03c5\u03b1",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "234335963269949",
#    "category": "Internet/Software",
#    "name": "Social Web Promotions"
#   },
#   {
#    "id": "1388018764754564",
#    "category": "Professional Services",
#    "name": "Free Social Media Webinars"
#   },
#   {
#    "id": "19939664284",
#    "category": "Local Business",
#    "name": "WebSocialTraffic"
#   },
#   {
#    "id": "853892051289097",
#    "category": "Software",
#    "name": "SocialWebshop Poland"
#   },
#   {
#    "id": "173522596056244",
#    "category": "Internet/Software",
#    "name": "Enspire | Web Development, Online Marketing and Social Media Management"
#   },
#   {
#    "id": "1410494762513204",
#    "category": "Consulting/Business Services",
#    "name": "Immedya - Mall Cinema Social Web",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "147374031981368",
#    "category": "News/Media Website",
#    "name": "Social Media Manager | Web e Social Media Marketing"
#   },
#   {
#    "id": "54677574397",
#    "category": "Local Business",
#    "name": "Leslie Trosset-Social Media-SEO-Expert-Web Design-Albany NY",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "163775863785154",
#    "category": "Book",
#    "name": "Texten f\u00fcrs Social Web"
#   },
#   {
#    "id": "119846254710406",
#    "category": "Internet/Software",
#    "name": "Complete Dreams Design - Web, Social, Graphic, and Video Design",
#    "category_list": [
#     {
#      "id": "2256",
#      "name": "Internet/Software"
#     }
#    ]
#   },
#   {
#    "id": "416689008392125",
#    "category": "Computers/Technology",
#    "name": "Social Media Webster"
#   },
#   {
#    "id": "173272359544586",
#    "category": "Community Organization",
#    "name": "Social Web Tech Talk"
#   },
#   {
#    "id": "153165781376857",
#    "category": "Local Business",
#    "name": "Media Villages - Mobile Responsive Social Media Centric Web Design.",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "136141159759477",
#    "category": "Local Business",
#    "name": "SuperSites Web Design & Social Marketing"
#   },
#   {
#    "id": "792128034233799",
#    "category": "Website",
#    "name": "Social Lead Marketing and Web Development"
#   },
#   {
#    "id": "503048753168925",
#    "category": "Professional Services",
#    "name": "RaDiO SoCiAL - Web Radio",
#    "category_list": [
#     {
#      "id": "169056916473899",
#      "name": "Broadcasting & Media Production"
#     }
#    ]
#   },
#   {
#    "id": "206788172841236",
#    "category": "Community",
#    "name": "Social Web Solutions"
#   },
#   {
#    "id": "17227796900",
#    "category": "Local Business",
#    "name": "Bravo Media [web/mobile/social] London //Rio de Janeiro",
#    "category_list": [
#     {
#      "id": "210659552293602",
#      "name": "Roller Coaster"
#     }
#    ]
#   },
#   {
#    "id": "432946513540737",
#    "category": "Internet/Software",
#    "name": "Social Media Web"
#   },
#   {
#    "id": "111024585626835",
#    "category": "Consulting/Business Services",
#    "name": "Networking Wins - Social Networking Management and Web/Graphic Design",
#    "category_list": [
#     {
#      "id": "2248",
#      "name": "Consulting/Business Services"
#     }
#    ]
#   },
#   {
#    "id": "117185225027930",
#    "category": "Internet/Software",
#    "name": "Meta Social Web"
#   },
#   {
#    "id": "1457097614589756",
#    "category": "Business Services",
#    "name": "Kali's Web & Social Management",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "292769827406517",
#    "category": "Local Business",
#    "name": "Marketing Web Social"
#   },
#   {
#    "id": "248823435257496",
#    "category": "Consulting/Business Services",
#    "name": "Social Web Consulting"
#   },
#   {
#    "id": "419507011456285",
#    "category": "School",
#    "name": "Social web - \u05e1\u05d5\u05e9\u05d9\u05d0\u05dc \u05d5\u05d5\u05d1"
#   },
#   {
#    "id": "369613539636",
#    "category": "Consulting/Business Services",
#    "name": "webfeuer - Social Media und mehr!"
#   },
#   {
#    "id": "208744325821683",
#    "category": "Internet/Software",
#    "name": "SocialEnterpriseWebsites.com"
#   },
#   {
#    "id": "172670552803004",
#    "category": "Computers/Internet Website",
#    "name": "Web/Social Marketing"
#   },
#   {
#    "id": "121637227912375",
#    "category": "Local Business",
#    "name": "MX - web & social marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "1562004210724084",
#    "category": "Consulting/Business Services",
#    "name": "Riviste & Co. - Magazine, Web Content, Social -",
#    "category_list": [
#     {
#      "id": "191684877517919",
#      "name": "Publisher"
#     }
#    ]
#   },
#   {
#    "id": "186923664693877",
#    "category": "Internet/Software",
#    "name": "Social Web Ecosystem"
#   },
#   {
#    "id": "114852928532072",
#    "category": "Personal Website",
#    "name": "THE JAGUAR SOCIAL NETWORK  WEBSITE"
#   },
#   {
#    "id": "883116528376991",
#    "category": "Company",
#    "name": "Right Track Media - Web Design, Social Media, Video",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "162183907165552",
#      "name": "Graphic Design"
#     }
#    ]
#   },
#   {
#    "id": "641989875880917",
#    "category": "Community",
#    "name": "Social Nurse Web"
#   },
#   {
#    "id": "127537383928865",
#    "category": "Consulting/Business Services",
#    "name": "CDA - web site design and social media marketing",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "199732070036794",
#      "name": "Artistic Services"
#     }
#    ]
#   },
#   {
#    "id": "127425098113",
#    "category": "Computers/Internet Website",
#    "name": "Seclang \"Social Networking Website\""
#   },
#   {
#    "id": "453613371345754",
#    "category": "Local Business",
#    "name": "Onefoursix - Specialists in Design, Print, Social Media, and Websites.",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "197888373555475",
#      "name": "Printing Service"
#     }
#    ]
#   },
#   {
#    "id": "953563847998448",
#    "category": "Professional Services",
#    "name": "VO double Web & Social",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "640045259452124",
#    "category": "Product/Service",
#    "name": "Social Web macht Schule"
#   },
#   {
#    "id": "806157402782310",
#    "category": "Community",
#    "name": "Social Web Urls"
#   },
#   {
#    "id": "524185097668322",
#    "category": "Computers/Technology",
#    "name": "Fresh - Social media, web & adv",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "337099466391403",
#    "category": "Small Business",
#    "name": "M&D Web+Socialmedia"
#   },
#   {
#    "id": "760164607375916",
#    "category": "TV Network",
#    "name": "Ceflix social web tv"
#   },
#   {
#    "id": "190870261096138",
# ...
#   },
#   {
#    "id": "159735864118250",
#    "category": "Community",
#    "name": "Social Webs"
#   },
#   {
#    "id": "877768845627602",
#    "category": "Website",
#    "name": "Web Social Shares 3"
#   },
#   {
#    "id": "182389758601535",
#    "category": "Community",
#    "name": "All Social Web"
#   },
#   {
#    "id": "369153603178816",
#    "category": "Consulting/Business Services",
#    "name": "Shlomo Walt's Creative Website Writing and Social Media Services"
#   },
#   {
#    "id": "249121281780512",
#    "category": "Professional Services",
#    "name": "CompXWeb - Web Design, Development & Social Media",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "164269200441810",
#    "category": "Community",
#    "name": "Social Web Real Estate"
#   },
#   {
#    "id": "235275659871189",
#    "category": "Consulting/Business Services",
#    "name": "Christa Goede: Text, Websites, Social Media.",
#    "category_list": [
#     {
#      "id": "164886566892249",
#      "name": "Advertising Agency"
#     }
#    ]
#   },
#   {
#    "id": "202329819852360",
#    "category": "Book",
#    "name": "Personalsuche im Social Web"
#   },
#   {
#    "id": "277644225667373",
#    "category": "Just For Fun",
#    "name": "Social web balls."
#   },
#   {
#    "id": "109692079082500",
#    "category": "Company",
#    "name": "Zero It | Websites | Development | Smartphone Apps | SEO | Social Media |",
#    "category_list": [
#     {
#      "id": "2200",
#      "name": "Company"
#     }
#    ]
#   },
#   {
#    "id": "149184731910179",
#    "category": "TV Show",
#    "name": "Social Web Cafe TV"
#   },
#   {
#    "id": "1488750614743981",
#    "category": "Community",
#    "name": "Happy Social Web"
#   },
#   {
#    "id": "336710475307",
#    "category": "Local Business",
#    "name": "Cire Web Design & Social Media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     }
#    ]
#   },
#   {
#    "id": "442967842428284",
#    "category": "Local Business",
#    "name": "Internet Builder Consulting Websites, SEO & Social Marketing Experts",
#    "category_list": [
#     {
#      "id": "179672275401610",
#      "name": "Business Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "207341495979989",
#    "category": "Consulting/Business Services",
#    "name": "Web Buzzr Social Media"
#   },
#   {
#    "id": "139130086152214",
#    "category": "Community",
#    "name": "Social Web Guide"
#   },
#   {
#    "id": "123171147695069",
#    "category": "Business Person",
#    "name": "Mirna Bard - Social Media Strategy Consultant, Trainer, Speaker & Author"
#   },
#   {
#    "id": "863399557029348",
#    "category": "Internet/Software",
#    "name": "Matteus Web Social"
#   },
#   {
#    "id": "273733899478961",
#    "category": "Community",
#    "name": "SocialWeb.Marketing"
#   },
#   {
#    "id": "146747499036670",
#    "category": "Media/News/Publishing",
#    "name": "Webuzz - Gets You Social",
#    "category_list": [
#     {
#      "id": "2233",
#      "name": "Media/News/Publishing"
#     }
#    ]
#   },
#   {
#    "id": "184400038262157",
#    "category": "Community",
#    "name": "Web Social Fusion"
#   },
#   {
#    "id": "198866480158068",
#    "category": "News/Media Website",
#    "name": "Social Web Media"
#   },
#   {
#    "id": "553637281423867",
#    "category": "Computers/Internet Website",
#    "name": "Music Video Promotion - Social Media By Siti Web"
#   },
#   {
#    "id": "213870391977281",
#    "category": "Non-Profit Organization",
#    "name": "Social Media Club Davis/Weber"
#   },
#   {
#    "id": "180012895477291",
#    "category": "Society/Culture Website",
#    "name": "Bee Social"
#   },
#   {
#    "id": "128655320529070",
#    "category": "Computers/Internet Website",
#    "name": "Super Socialites| Web Design-Social Media & Marketing"
#   },
#   {
#    "id": "121361064703333",
#    "category": "News/Media Website",
#    "name": "Social Media Websites"
#   },
#   {
#    "id": "160950113952562",
#    "category": "Community",
#    "name": "WebSocial Technologies"
#   },
#   {
#    "id": "1756015064630621",
#    "category": "Media/News/Publishing",
#    "name": "Social Bookmarking Website"
#   },
#   {
#    "id": "132367610218395",
#    "category": "Local Business",
#    "name": "Social Media Akademie (Webculture Gmbh)",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "470801116442908",
#    "category": "Consulting/Business Services",
#    "name": "The Social Web"
#   },
#   {
#    "id": "645061782205988",
#    "category": "Community",
#    "name": "Social Web Buys"
#   },
#   {
#    "id": "1374450889478885",
#    "category": "Professional Services",
#    "name": "Barcino Dise\u00f1o Web LOW COST y Social Media Barcelona",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "508178575883032",
#    "category": "Consulting/Business Services",
#    "name": "Social Media Webinarcamps"
#   },
#   {
#    "id": "168072826666497",
#    "category": "Entertainment Website",
#    "name": "In Social Web"
#   },
#   {
#    "id": "616960891669526",
#    "category": "Company",
#    "name": "Donkrea Agencia Dise\u00f1o Web y Social Media",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "161519650568794",
#    "category": "Church/Religious Organization",
#    "name": "Kirche im Web 2.0 / Social Media"
#   },
#   {
#    "id": "484885424999607",
#    "category": "Consulting/Business Services",
#    "name": "Andrea Pilotti - Web Marketing & Social Media"
#   },
#   {
#    "id": "109041179115289",
#    "category": "Media/News/Publishing",
#    "name": "Soul Space Graphic, Web Design & Social Media",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "1450059198607934",
#    "category": "Website",
#    "name": "Social/News/Culture Website"
#   },
#   {
#    "id": "196298563744277",
#    "category": "Company",
#    "name": "Hi Fi Social Web"
#   },
#   {
#    "id": "159918207405302",
#    "category": "Local Business",
#    "name": "Social Web Consulting Test Page",
#    "category_list": [
#     {
#      "id": "176831012360626",
#      "name": "Professional Services"
#     }
#    ]
#   },
#   {
#    "id": "131829320161316",
#    "category": "Local Business",
#    "name": "Ewing Enterprise - Custom Website Packages, SEO Services,  Social Media",
#    "category_list": [
#     {
#      "id": "2500",
#      "name": "Local Business"
#     }
#    ]
#   },
#   {
#    "id": "259193520907269",
#    "category": "Consulting/Business Services",
#    "name": "ARMO PS - Social Marketing & Webs",
#    "category_list": [
#     {
#      "id": "163272113725616",
#      "name": "Advertising Service"
#     }
#    ]
#   },
#   {
#    "id": "245057172212562",
#    "category": "News/Media Website",
#    "name": "SocialWebSeries"
#   },
#   {
#    "id": "335936979775976",
#    "category": "Education",
#    "name": "Social Web Class"
#   },
#   {
#    "id": "240427305985706",
#    "category": "Professional Services",
#    "name": "M4 design, Web, Social Media, Videos",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     }
#    ]
#   },
#   {
#    "id": "585427021523043",
#    "category": "Product/Service",
#    "name": "Packetmanxd - Web Design & Social Media"
#   },
#   {
#    "id": "229579083743042",
#    "category": "Local Business",
#    "name": "Web & Social"
#   },
#   {
#    "id": "1228165387210147",
#    "category": "Community",
#    "name": "Social Web"
#   },
#   {
#    "id": "1542982969346291",
#    "category": "Small Business",
#    "name": "Katie Williamsen Web + Social Media Consulting, LLC"
#   },
#   {
#    "id": "172143232826805",
#    "category": "Community",
#    "name": "Web&Social&Mobile"
#   },
#   {
#    "id": "301049839941854",
#    "category": "Website",
#    "name": "Social Media Domains, Websites and More"
#   },
#   {
#    "id": "291685730849374",
#    "category": "Internet/Software",
#    "name": "WBS Net - Web Brokerage Social Network",
#    "category_list": [
#     {
#      "id": "143973032336164",
#      "name": "Brokers & Franchising"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "139745066094977",
#      "name": "Business Center"
#     }
#    ]
#   },
#   {
#    "id": "241894749184616",
#    "category": "Consulting/Business Services",
#    "name": "iptaque, web social, formation"
#   },
#   {
#    "id": "155755994459126",
#    "category": "Community",
#    "name": "NUZ - Social Web Tv"
#   },
#   {
#    "id": "522531034450480",
#    "category": "Business Services",
#    "name": "Website Social Media Development",
#    "category_list": [
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "703086309803053",
#    "category": "Business Services",
#    "name": "Websites for small business",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "395067077366300",
#    "category": "Computers/Internet Website",
#    "name": "Web-social net"
#   },
#   {
#    "id": "259629940911495",
#    "category": "Business Services",
#    "name": "L'Operosa Social Web",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "262868793734822",
#    "category": "Computers/Technology",
#    "name": "WebSocial2.0"
#   },
#   {
#    "id": "273795329402044",
#    "category": "Business Services",
#    "name": "Justin Mulder - Web Design & Social Media Consultant",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "367184530117710",
#    "category": "Community",
#    "name": "Authors on social web"
#   },
#   {
#    "id": "327406427374649",
#    "category": "Internet/Software",
#    "name": "Esbie Web & Social Media"
#   },
#   {
#    "id": "705406856226655",
#    "category": "Organization",
#    "name": "Social likes in web"
#   },
#   {
#    "id": "537321239622767",
#    "category": "Computers/Internet Website",
#    "name": "The Social Media Web Genie"
#   },
#   {
#    "id": "196321800413834",
#    "category": "Small Business",
#    "name": "Social Impact Web"
#   },
#   {
#    "id": "162081643861223",
#    "category": "Business Services",
#    "name": "Web Social Marketing",
#    "category_list": [
#     {
#      "id": "367960506579477",
#      "name": "Arts & Marketing"
#     },
#     {
#      "id": "187133811318958",
#      "name": "Business Services"
#     }
#    ]
#   },
#   {
#    "id": "1668902670065492",
#    "category": "Community",
#    "name": "Webcomics Social"
#   },
#   {
#    "id": "454451468008331",
#    "category": "Internet/Software",
#    "name": "Web Douro at Social Media Networking"
#   },
#   {
#    "id": "653130718079993",
#    "category": "Product/Service",
#    "name": "Webmeister Social SEO"
#   },
#   {
#    "id": "162283363841443",
#    "category": "Internet/Software",
#    "name": "Eager Beaver Media: Web, social media and SEO for businesses"
#   },
#   {
#    "id": "240539769321965",
#    "category": "News/Media Website",
#    "name": "Web Analytics, Social Media and Digital marketing"
#   },
#   {
#    "id": "1598366860430649",
#    "category": "Interest",
#    "name": "Max Weber Center for Advanced Cultural and Social Studies"
#   },
#   {
#    "id": "1560556784228023",
#    "category": "Consulting/Business Services",
#    "name": "Mirko Paganelli Web Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "121168127989143",
#    "category": "Local Business",
#    "name": "RamCage Social Web Portals"
#   },
#   {
#    "id": "910500438966224",
#    "category": "Community",
#    "name": "Web Social Consultery"
#   },
#   {
#    "id": "509251595812044",
#    "category": "Personal Website",
#    "name": "V Crown Social website"
#   },
#   {
#    "id": "628817540514835",
#    "category": "Professional Services",
#    "name": "Web Marketing & Social Media Marketing",
#    "category_list": [
#     {
#      "id": "170992992946914",
#      "name": "Marketing Consultant"
#     }
#    ]
#   },
#   {
#    "id": "301443150054791",
#    "category": "Internet/Software",
#    "name": "Design Social Web"
#   },
#   {
#    "id": "549404525226000",
#    "category": "Business Services",
#    "name": "Social Media web 2.0",
#    "category_list": [
#     {
#      "id": "206534229374185",
#      "name": "Email Marketing"
#     },
#     {
#      "id": "187215161312096",
#      "name": "Internet Service Provider"
#     }
#    ]
#   },
#   {
#    "id": "475543625793316",
#    "category": "Website",
#    "name": "SocialProofWeb"
#   },
#   {
#    "id": "1546362885620833",
#    "category": "Consulting/Business Services",
#    "name": "Mi Web Social"
#   },
#   {
#    "id": "817713454916961",
#    "category": "Community",
#    "name": "Social Webs Likes And Fans Service"
#   },
#   {
#    "id": "516074525237823",
#    "category": "Product/Service",
#    "name": "Social Business webshop"
#   },
#   {
#    "id": "115071465275402",
#    "category": "Community",
#    "name": "CmronWeb Social Community"
#   },
#   {
#    "id": "281602695213851",
#    "category": "Small Business",
#    "name": "Caltak Enterprises Web Design, Consulting, & Social Media"
#   },
#   {
#    "id": "83659087689",
#    "category": "Non-Profit Organization",
#    "name": "Second Wednesday - Web industry social events"
#   },
#   {
#    "id": "201920803163928",
#    "category": "Internet/Software",
#    "name": "Mais4 Social Web"
#   },
#   {
#    "id": "690442864339111",
#    "category": "Company",
#    "name": "Mellissa Webster: Content Creation and Social Media Strategist For Hire",
#    "category_list": [
#     {
#      "id": "186573994697103",
#      "name": "Writing Service"
#     }
#    ]
#   },
#   {
#    "id": "666423320041020",
#    "category": "Community",
#    "name": "Social Web Shares"
#   },
#   {
#    "id": "1461332314093628",
#    "category": "Entertainment Website",
#    "name": "Social Media on The Web Desk"
#   },
#   {
#    "id": "91655339434",
#    "category": "Community",
#    "name": "Comwerk Webdesign & Social Media"
#   },
#   {
#    "id": "272044382898925",
#    "category": "Consulting/Business Services",
#    "name": "Esther Szczerba - Web & Marketing Solutions, Social Media"
#   },
#   {
#    "id": "105033309531917",
#    "category": "Society/Culture Website",
#    "name": "Kwamla's Society, History, Culture & Social Media WebSite"
#   },
#   {
#    "id": "1005888506148602",
#    "category": "Website",
#    "name": "Social Web Coach"
#   },
#   {
#    "id": "455357827936421",
#    "category": "Internet/Software",
#    "name": "Modo web & social media",
#    "category_list": [
#     {
#      "id": "187393124625179",
#      "name": "Web Design"
#     },
#     {
#      "id": "200154933429705",
#      "name": "Web Development"
#     }
#    ]
#   },
#   {
#    "id": "835827246464525",
#    "category": "News/Media Website",
#    "name": "Social Web Marketing Italia"
#   },
#   {
#    "id": "1409211522669854",
#    "category": "Product/Service",
#    "name": "Social Media Website"
#   },
#   {
#    "id": "51426770632",
#    "category": "Public Figure",
#    "name": "Web Success Diva Social Internet Marketing"
#   },
#   {
#    "id": "1025386394149310",
#    "category": "Business Person",
#    "name": "Alison Kenny- Web Design & Social Media"
#   },
#   {
#    "id": "202259563440484",
#    "category": "Small Business",
#    "name": "Canadian Social Web Jedis"
#   },
#   {
#    "id": "309361589082975",
#    "category": "App Page",
#    "name": "Social Web to Print"
#   },
#   {
#    "id": "1572105146400608",
#    "category": "Consulting/Business Services",
#    "name": "Stratageme Equestrian Riding & Web/Social Media Management"
#   },
#   {
#    "id": "182392658453258",
#    "category": "Community",
#    "name": "Social Media Web Solutions"
#   },
#   {
#    "id": "901583179936531",
#    "category": "Community",
#    "name": "Carnegie Mellon Social Web"
#   }
#  ]
# }

# %% [markdown]
# ## Example 3. Results for a Graph API query for Mining the Social Web

# %%
# Get an instance of Mining the Social Web
# Using the page name also works if you know it.
# e.g. 'MiningTheSocialWeb' or 'CrossFit'
mtsw_id = '146803958708175'
pp(g.get_object(mtsw_id))
# Out:
# {
#  "username": "MiningTheSocialWeb",
#  "name": "Mining the Social Web",
#  "mission": "Teaches you how to navigate the most popular social web APIs to access, collect, analyze, and visualize social web data with IPython Notebook and other easy to use Python packages and visualization tools.",
#  "talking_about_count": 11,
#  "id": "146803958708175",
#  "category": "Book",
#  "has_added_app": false,
#  "link": "https://www.facebook.com/MiningTheSocialWeb/",
#  "release_date": "January 2011",
#  "is_community_page": false,
#  "is_published": true,
#  "awards": "Jolt Productivity Award (1st Ed.) -  http://drdobbs.com/joltawards/231500080?pgno=6",
#  "likes": 2369,
#  "company_overview": "Like It here on Facebook!\n\nFollow @SocialWebMining on Twitter: http://twitter.com/SocialWebMining\n\nGet the source code for the revised and expanded second edition on GitHub: http://bit.ly/MiningTheSocialWeb2E\n\nGet the (now legacy) source code for the first edition on GitHub: http://bit.ly/SocialWebMining",
#  "about": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites. Twitter: @SocialWebMining",
#  "general_info": "Analyzing Data from Facebook, Twitter, LinkedIn, and Other Social Media Sites - Get it at http://bit.ly/135dHfs",
#  "checkins": 0,
#  "were_here_count": 0,
#  "cover": {
#   "id": "522831997772034",
#   "offset_x": 0,
#   "offset_y": 56,
#   "cover_id": "522831997772034",
#   "source": "https://scontent.xx.fbcdn.net/hphotos-frc3/t31.0-0/p180x540/1073953_522831997772034_741301400_o.jpg"
#  },
#  "parking": {
#   "lot": 0,
#   "valet": 0,
#   "street": 0
#  },
#  "founded": "January 2011",
#  "genre": "Data Mining",
#  "website": "http://miningthesocialweb.com",
#  "description": "Facebook, Twitter, LinkedIn, Google+, and other social web properties generate a wealth of valuable social data, but how can you tap into this data and discover who\u2019s connecting with whom, which insights are lurking just beneath the surface, and what people are talking about? This book shows you how to answer these questions and many more. Each chapter combines popular and useful social web data with analysis techniques and visualization to help you find the needles in the social haystack that you've been looking for\u2014as well as many you probably didn't even know existed.\n\nIn this expanded and thoroughly revised second edition you\u2019ll learn how to:\n\n* Navigate the most popular social web APIs to access, collect, analyze, and visualize social web data\n* Employ IPython Notebook and other easy to use Python packages such as the Natural Language Toolkit, NetworkX, and Matplotlib to efficiently sift through social web data as part of an experimentally-driven approach to discovering insights in social web data\n* Apply advanced text-mining techniques such as TF-IDF, cosine similarity, collocation analysis, document summarization, and clique detection to human language data that you'll encounter all over the web\n* Bootstrap interest graphs by discovering latent affinities between people, programming languages, and coding projects from GitHub data\n* Visualize social web data with D3, a state-of-the-art HTML5 and JavaScript toolkit\n\nThe book's source code is maintained in a GitHub repository maintained by the author and can be deployed as turn-key virtual machine with each chapter's source code presented in an interactive and easy to use IPython Notebook format. No complex third-party installations or advanced Python knowledge is required to get the most out of this book.",
#  "can_post": true
# }

# %% [markdown]
# ## Example 4. Querying the Graph API for Open Graph objects by their URLs

# %%
# MTSW catalog link
pp(g.get_object('http://shop.oreilly.com/product/0636920030195.do'))

# PCI catalog link
pp(g.get_object('http://shop.oreilly.com/product/9780596529321.do'))
# Out:
# {
#  "id": "http://shop.oreilly.com/product/0636920030195.do",
#  "shares": 280
# }
# {
#  "likes": 17,
#  "about": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "talking_about_count": 0,
#  "checkins": 0,
#  "id": "221689464577245",
#  "category": "Book",
#  "has_added_app": false,
#  "were_here_count": 0,
#  "name": "Programming Collective Intelligence",
#  "link": "http://shop.oreilly.com/product/9780596529321.do",
#  "is_community_page": false,
#  "is_published": true,
#  "description": "This fascinating book demonstrates how you can build web applications to mine the enormous amount of data created by people on the Internet. With the sophisticated algorithms in this book, you can write smart programs to access interesting datasets f...",
#  "parking": {
#   "lot": 0,
#   "valet": 0,
#   "street": 0
#  },
#  "can_post": true
# }

# %% [markdown]
# ## Example 5. Comparing likes between Coke and Pepsi fan pages

# %%
# Find Pepsi and Coke in search results

pp(g.request('search', {'q' : 'pepsi', 'type' : 'page', 'limit' : 5}))
pp(g.request('search', {'q' : 'coke', 'type' : 'page', 'limit' : 5}))

# Use the ids to query for likes

pepsi_id = '56381779049' # Could also use 'PepsiUS'
coke_id = '40796308305'  # Could also use 'CocaCola'

# A quick way to format integers with commas every 3 digits
def int_format(n): return "{:,}".format(n)

print(g.get_object(pepsi_id).keys())
print ("Pepsi likes:", int_format(g.get_object(pepsi_id)['likes']))
print ("Coke likes:", int_format(g.get_object(coke_id)['likes']))
# Out:
# {
#  "paging": {
#   "cursors": {
#    "after": "NAZDZD",
#    "before": "MAZDZD"
#   },
#   "next": "https://graph.facebook.com/v2.0/search?access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD&q=pepsi&type=page&limit=5&after=NAZDZD"
#  },
#  "data": [
#   {
#    "id": "260431051694",
#    "category": "Food/Beverages",
#    "name": "PepsiCo",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ]
#   },
#   {
#    "id": "63619711274",
#    "category": "Food/Beverages",
#    "name": "Pepsithai"
#   },
#   {
#    "id": "155245951177329",
#    "category": "Food/Beverages",
#    "name": "Pepsi SA",
#    "category_list": [
#     {
#      "id": "2252",
#      "name": "Food/Beverages"
#     }
#    ]
#   },
#   {
#    "id": "111829892187838",
#    "category": "Company",
#    "name": "Pepsi Center",
#    "category_list": [
#     {
#      "id": "109976259083543",
#      "name": "Sports Venue & Stadium"
#     },
#     {
#      "id": "179943432047564",
#      "name": "Concert Venue"
#     },
#     {
#      "id": "211155112228091",
#      "name": "Event Venue"
#     }
#    ]
#   },
#   {
#    "id": "131381520241235",
#    "category": "Food/Beverages",
#    "name": "Pepsi MAX"
#   }
#  ]
# }
# {
#  "paging": {
#   "cursors": {
#    "after": "NAZDZD",
#    "before": "MAZDZD"
#   },
#   "next": "https://graph.facebook.com/v2.0/search?access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD&q=coke&type=page&limit=5&after=NAZDZD"
#  },
#  "data": [
#   {
#    "id": "16944632531",
#    "category": "TV Show",
#    "name": "Coke Studio"
#   },
#   {
#    "id": "204637709677777",
#    "category": "Real Estate",
#    "name": "Coke Luxe",
#    "category_list": [
#     {
#      "id": "133436743388217",
#      "name": "Arts & Entertainment"
#     },
#     {
#      "id": "186982054657561",
#      "name": "Sports & Recreation"
#     }
#    ]
#   },
#   {
#    "id": "40671371171",
#    "category": "Education",
#    "name": "Coker College",
#    "category_list": [
#     {
#      "id": "108051929285833",
#      "name": "College & University"
#     }
#    ]
#   },
#   {
#    "id": "684491471670573",
#    "category": "Food/Beverages",
#    "name": "Coca-Cola"
#   },
#   {
#    "id": "242860985744106",
#    "category": "Community Organization",
#    "name": "Coke Cup Thailand"
#   }
#  ]
# }
# dict_keys(['username', 'cover', 'about', 'likes', 'checkins', 'id', 'category', 'has_added_app', 'were_here_count', 'global_brand_root_id', 'link', 'is_community_page', 'talking_about_count', 'is_published', 'website', 'description', 'parking', 'can_post', 'name'])
# Pepsi likes: 34,770,450
# Coke likes: 96,495,055

# %% [markdown]
# ## Example 6. Querying a page for its "feed" and "links" connections

# %%
pp(g.get_connections(pepsi_id, 'feed'))
pp(g.get_connections(pepsi_id, 'links'))

pp(g.get_connections(coke_id, 'feed'))
pp(g.get_connections(coke_id, 'links'))
# Out:
# {
#  "paging": {
#   "previous": "https://graph.facebook.com/v2.0/56381779049/feed?since=1456103862&access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD&limit=25&__paging_token=enc_AdATb1gHzP1Tx3Vn8hxPLG8A0fiov6fkNwT5QzxlZArLF6tXpJThMi1jTrLBvQtNQ4ChxTSQYpCcDNZCpvgrC1GHXI&__previous=1",
#   "next": "https://graph.facebook.com/v2.0/56381779049/feed?access_token=CAACEdEose0cBAMHYQOjaSnirGZAWXuhaZAsy5587gEvfRxYubZALVsmj5Gb82GUNoZBXghz6JDjHRg616r6OJOjdN4ZCgJtuNpfhUqjQI8LPTNQdgqvWmZAYjas9h68Qx7mOpXCZCnj8eAkkNL67dxSiPRASpoxIo5UcQpZA3kY0olAGPOjhvtzhWT1BdjUGyFgxcYQKXpEiVwZDZD&limit=25&until=1455847475&__paging_token=enc_AdAe1L8F3E035HlEZA6pRD7l7eZA5KYCbtTgOJzRMlmWb8eQXW8ZBYr9ZBosR4hwJDkfqZCF4oW374Rmkhd6cEeHtKTa4"
#  },
#  "data": [
#   {
#    "from": {
#     "id": "636423999780192",
#     "name": "Amber Renee Knight"
#    },
#    "type": "photo",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/photo.gif",
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xft1/v/t1.0-0/s130x130/12715352_999574070131848_4078485485869668221_n.jpg?oh=66b9e8ad59eb2f85442bcf3db73a53b9&oe=575CA756",
#    "id": "56381779049_999574070131848",
#    "object_id": "999574070131848",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/999574070131848",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/999574070131848",
#      "name": "Like"
#     },
#     {
#      "link": "https://m.facebook.com/friendship/100002377937188/56381779049/",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2016-02-22T01:17:42+0000",
#    "link": "https://www.facebook.com/photo.php?fbid=999574070131848&set=o.56381779049&type=3",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-22T01:17:42+0000",
#    "message": "This would be pretty awesome if Pepsi did this for Memorial Day, Fourth of July or Veterans Day. Better yet, if they created a special flavor and it had this tribute on the label all year long.",
#    "is_expired": false,
#    "status_type": "added_photos"
#   },
#   {
#    "from": {
#     "id": "10204963848315707",
#     "name": "Brandon Gradelle Smith"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154119393544050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154119393544050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154119393544050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-21T23:59:13+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-21T23:59:13+0000",
#    "message": "Seriously, put aspartame back in Diet Pepsi. Please.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "1017191851675883",
#     "name": "Kenneth Lander"
#    },
#    "type": "link",
#    "name": "Click here to support MY COLLEGE TUITION ASSISTANCE FUND by Kenneth Lander",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQD2UiAH0qO6xTsb&w=130&h=130&url=http%3A%2F%2Ffunds.gfmcdn.com%2F9208881_1455799951.9332.jpg&cfs=1&sx=166&sy=0&sw=533&sh=533",
#    "id": "56381779049_1018736368188098",
#    "caption": "gofundme.com",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1018736368188098",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/1018736368188098",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-21T23:50:22+0000",
#    "link": "https://www.gofundme.com/collegetuitiongive",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-21T23:50:22+0000",
#    "description": "Hey everyone. As many of you know, I am currently attending San Diego State University in the graduating Class of 2019. Being an out-of-state student, I was aware that college would be very expensive, however I'm finally in enough of a pickle to ask for some help. California has always been home...",
#    "message": "COLLEGE TUITION FUNDRAISER HELP PLEASE\n\nI'm posting this for a friend who needs quick and kind assistance with his College Tuition if you can help?. His name is Bryan and he needs assistance and would and greatly appreciate it if you would help him by donating in any way you can. Please read his short story at the link below and consider helping him. You can quickly donate with Paypal by clicking this link. https://www.gofundme.com/collegetuitiongive\n\nMost students and/or their families who pay for College Tuition and other education costs don't have enough savings to pay in full while they are in school. Some students must work and/or borrow money to afford an education. GoFundMe is a trusted crowdfunding platform used by millions including celebrities that allows people to raise money for events ranging from life events such as celebrations and graduations to challenging circumstances like accidents and illnesses. The company is based in San Diego, California.\n\nhttps://www.gofundme.com/collegetuitiongive\n\n",
#    "is_expired": false,
#    "status_type": "shared_story"
#   },
#   {
#    "from": {
#     "id": "982760885143619",
#     "name": "Amidude Ninetynine"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154119080979050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154119080979050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154119080979050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-21T20:47:35+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-21T20:47:35+0000",
#    "message": "Please back off ur robo cap installers. Lately you just about sprain ur hand trying to open a bottle. And just now we opened one to find the plastic threads actually broken and the broken jagged piece fell out.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "324251694366500",
#     "name": "Jose Rodriguez"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154117946109050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154117946109050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154117946109050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-21T08:23:37+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-21T08:23:37+0000",
#    "message": "I ' am Interesting In earning thru your Referal Program. Thank you for your attention",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "10203665537513359",
#     "name": "Gerry Flynn-Austin"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154116359774050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154116359774050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154116359774050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T17:26:04+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T17:26:04+0000",
#    "message": "Is there a secret to navigating Pepsico website? I have attempted to email about an ongoing problem and can't input information requested. I have called several times but the problem has not been addressed. I guess loyal consumers don't rate.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "10207239003085480",
#     "name": "Patti Bliss Sands"
#    },
#    "type": "photo",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTAyMDMwMjIwNDY2NTY0NDE=",
#       "before": "Mzg5Mjc2MDY0NTQ4MDE1"
#      }
#     },
#     "data": [
#      {
#       "id": "389276064548015",
#       "name": "Chris Gardner"
#      },
#      {
#       "id": "531019987018709",
#       "name": "Elaine Crosby"
#      },
#      {
#       "id": "10203022046656441",
#       "name": "Cynthia Miller Eigenmann"
#      }
#     ]
#    },
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/photo.gif",
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xlf1/v/t1.0-0/s130x130/12705794_10207355146268987_2507839577829021656_n.jpg?oh=399f5e060e474f13a88927021d63d4ef&oe=576E40C9",
#    "id": "56381779049_10207355146268987",
#    "object_id": "10207355146268987",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10207355146268987",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10207355146268987",
#      "name": "Like"
#     },
#     {
#      "link": "https://m.facebook.com/friendship/1596034623/56381779049/",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2016-02-20T15:22:39+0000",
#    "link": "https://www.facebook.com/photo.php?fbid=10207355146268987&set=o.56381779049&type=3",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T15:22:39+0000",
#    "message": "My grandson got into the pantry to celebrate his first birthday and look what he picked",
#    "is_expired": false,
#    "status_type": "added_photos"
#   },
#   {
#    "from": {
#     "id": "10153029046238034",
#     "name": "Anamaria Arboleda"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154116143544050",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTM5MTE2Nzc3Nzg2OTY0Ng==",
#       "before": "MTM5MTE2Nzc3Nzg2OTY0Ng=="
#      }
#     },
#     "data": [
#      {
#       "id": "1391167777869646",
#       "name": "Krissy Jones"
#      }
#     ]
#    },
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154116143544050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154116143544050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T15:19:52+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T15:19:52+0000",
#    "message": "Hey PepsiCo, all of the advertising in the world won\u2019t cover up the forest destruction your snacks are linked to. Cut Conflict Palm Oil Now!",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "901825533163865",
#     "name": "James Carlson"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154115983824050",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTM5MTE2Nzc3Nzg2OTY0Ng==",
#       "before": "MTM5MTE2Nzc3Nzg2OTY0Ng=="
#      }
#     },
#     "data": [
#      {
#       "id": "1391167777869646",
#       "name": "Krissy Jones"
#      }
#     ]
#    },
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115983824050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115983824050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T13:27:36+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T13:27:36+0000",
#    "message": "DIET POP MAKES YOU FATTER THAN REGULAR SODA.  OTHERWISE EVERYONE WOULD BE SKINNY.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "10204289153406183",
#     "name": "Lacey Carpenter"
#    },
#    "type": "link",
#    "name": "moonshinebandits.com",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQDGPzPCkkqggI5x&w=130&h=130&url=http%3A%2F%2Fmoonshinebandits.com%2Fdeadman%2Fimages%2Fdeadman-splash_04.png&cfs=1",
#    "id": "56381779049_10206982482337723",
#    "caption": "moonshinebandits.com",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10206982482337723",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10206982482337723",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T09:28:35+0000",
#    "link": "http://moonshinebandits.com/",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T09:28:35+0000",
#    "message": "Go get Moonshine Bandits new CD #BLACKEDOUT http:// moonshinebandits.com #ShinerNation A great CD to listen to while enjoying a Pepsi!",
#    "is_expired": false,
#    "status_type": "shared_story"
#   },
#   {
#    "from": {
#     "id": "1618796221685623",
#     "category": "Library",
#     "name": "AMB Wallpapers"
#    },
#    "type": "link",
#    "name": "Pepsi HD Wallpaper",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQAwmS8li6Joq5l_&w=130&h=130&url=http%3A%2F%2Fwww.ambwallpapers.com%2Fwp-content%2Fuploads%2F2016%2F02%2FPepsi-HD-Wallpaper-with-Babes.jpg&cfs=1&sx=701&sy=0&sw=1200&sh=1200",
#    "id": "56381779049_10154115532744050",
#    "caption": "ambwallpapers.com",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115532744050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115532744050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T08:41:43+0000",
#    "link": "http://www.ambwallpapers.com/pepsi-hd-wallpaper/",
#    "message_tags": {
#     "36": [
#      {
#       "id": "339150749455906",
#       "type": "page",
#       "name": "Pepsi",
#       "length": 5,
#       "offset": 36
#      }
#     ]
#    },
#    "to": {
#     "data": [
#      {
#       "id": "339150749455906",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T08:41:43+0000",
#    "description": "Free download the magnificent collection of Pepsi HD Wallpaper. Just watch out the latest hd wallpapers, images & pics only at AMBWallpapers",
#    "message": "Pepsi HD Wallpaper\n#Pepsi  #Drinks  Pepsi",
#    "is_expired": false,
#    "status_type": "shared_story"
#   },
#   {
#    "from": {
#     "id": "1498846650360494",
#     "name": "Kimmy Benson"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154115367189050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115367189050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115367189050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T06:38:54+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T06:38:54+0000",
#    "message": "We want crystal Pepsi to make its come back no one will come to any of my parties and I blame my bland drink choices I bet if I said there was crystal clear Pepsi here everyone would show up. I know BYOF bring your own pet fish parties are a new thing but crystal clear Pepsi would really am things up we could sit around holding our fishes in bags drinking clear Pepsi and talking about fish food ratings in style. I don't want thi go to get to crazy but I could see some friends say I live on the edge with clear soda.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "707645052673492",
#     "name": "Lisa Oetting"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154115168809050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115168809050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154115168809050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T04:04:02+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T04:04:02+0000",
#    "message": "Why can I not find Pepsi made in Mexico anymore?",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "773732442698778",
#     "name": "Jeshua Leblanc"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154114989194050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114989194050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114989194050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T02:23:59+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T02:23:59+0000",
#    "message": "Love Your Explosive Pepsi aspartame free soda's  love how loud they are when i open them.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "445163752319101",
#     "name": "Chris Warbington"
#    },
#    "type": "photo",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MjgzNzM1Mjg4NDU2NTIx",
#       "before": "MTAxMDA2NzUzNDkyNjY1ODk="
#      }
#     },
#     "data": [
#      {
#       "id": "10100675349266589",
#       "name": "Ali Chesney"
#      },
#      {
#       "id": "283735288456521",
#       "name": "Tiffany Marie"
#      }
#     ]
#    },
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/photo.gif",
#    "picture": "https://scontent.xx.fbcdn.net/hphotos-xft1/v/t1.0-0/s130x130/12744270_552582848243857_4681767911457249743_n.jpg?oh=d6d037bccf9ee19818c4fac7280d46d5&oe=57556631",
#    "id": "56381779049_552582848243857",
#    "object_id": "552582848243857",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/552582848243857",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/552582848243857",
#      "name": "Like"
#     },
#     {
#      "link": "https://m.facebook.com/friendship/100004764393494/56381779049/",
#      "name": "See Friendship"
#     }
#    ],
#    "updated_time": "2016-02-20T01:56:47+0000",
#    "link": "https://www.facebook.com/photo.php?fbid=552582848243857&set=o.56381779049&type=3",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T01:56:47+0000",
#    "message": "You know you're the first mainstream cola to think about the Phenylketonuria community.  Thanks",
#    "is_expired": false,
#    "status_type": "added_photos"
#   },
#   {
#    "from": {
#     "id": "10154915103515368",
#     "name": "Saul Gonzalez"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154114781444050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114781444050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114781444050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-20T00:53:25+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-20T00:53:25+0000",
#    "message": "Guys bring back Pepsi Next. I just went to go buy some and now there discontinued? On your site it says it's available at all these stores too, but nothing. A lot of my family drink this as a alternative to pure sugared soda. If not is there some way I can buy some directly or?? Thanks",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "713172282094247",
#     "name": "Sharon Fricano"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154114577229050",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTM5MTE2Nzc3Nzg2OTY0Ng==",
#       "before": "MTM5MTE2Nzc3Nzg2OTY0Ng=="
#      }
#     },
#     "data": [
#      {
#       "id": "1391167777869646",
#       "name": "Krissy Jones"
#      }
#     ]
#    },
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114577229050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114577229050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T22:51:51+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T22:51:51+0000",
#    "message": "I will boycott anything to do with Pepsi as should others and any other company that endorsed half time show and will have family and friends do the same. No comment or apology from any of these companies",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "760062467345764",
#     "name": "Ricardo Gill"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154114336109050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114336109050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114336109050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T20:21:46+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T20:21:46+0000",
#    "message": "PEPSI HOCKEY.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "name": "Emojis Are Headed to a Pepsi Can Near You",
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQAlReL83znh-NH3&w=130&h=130&url=http%3A%2F%2Fassets.creativity-online.com%2Fimages%2Fwork%2Fprint%2Fp%2Fe%2Fp%2FPepsi_EmojiPackaging16.jpg&cfs=1",
#    "story_tags": {
#     "0": [
#      {
#       "id": "726261194094949",
#       "type": "page",
#       "name": "Emogi",
#       "length": 5,
#       "offset": 0
#      }
#     ]
#    },
#    "is_hidden": false,
#    "is_expired": false,
#    "link": "http://creativity-online.com/work/pepsi-emoji-packaging/45582",
#    "story": "Emogi feeling positive.",
#    "to": {
#     "data": [
#      {
#       "id": "339150749455906",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "updated_time": "2016-02-19T20:09:18+0000",
#    "from": {
#     "id": "726261194094949",
#     "category": "Internet/Software",
#     "name": "Emogi",
#     "category_list": [
#      {
#       "id": "2256",
#       "name": "Internet/Software"
#      }
#     ]
#    },
#    "type": "link",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "MTQxOTkzMjIyNDk5OTYxMw==",
#       "before": "MTE1NTc0MTA2NDQ0Mzc0MA=="
#      }
#     },
#     "data": [
#      {
#       "id": "1155741064443740",
#       "name": "Mayra Perez"
#      },
#      {
#       "id": "10202572184415846",
#       "name": "William Felipe Llanos"
#      },
#      {
#       "id": "10204479601061289",
#       "name": "Fred Iwan"
#      },
#      {
#       "id": "10204898244920915",
#       "name": "Alex Gentile"
#      },
#      {
#       "id": "1419932224999613",
#       "name": "Paul Eschbach"
#      }
#     ]
#    },
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114309994050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114309994050",
#      "name": "Like"
#     }
#    ],
#    "message_tags": {
#     "31": [
#      {
#       "id": "339150749455906",
#       "type": "page",
#       "name": "Pepsi",
#       "length": 5,
#       "offset": 31
#      }
#     ]
#    },
#    "caption": "creativity-online.com",
#    "id": "56381779049_10154114309994050",
#    "created_time": "2016-02-19T20:09:18+0000",
#    "description": "Emoji: Headed to a Pepsi Can Near You",
#    "message": "Emojis take a step in bridging Pepsi's retail marketing with digital marketing, and all without words.",
#    "status_type": "shared_story"
#   },
#   {
#    "from": {
#     "id": "675403795854473",
#     "name": "Dana Minzenberger"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154114254539050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114254539050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154114254539050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T19:46:00+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T19:46:00+0000",
#    "message": "Is crystal Pepsi still back?",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "127438014257232",
#     "name": "Ryan Nies"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154113675519050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113675519050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113675519050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T21:40:50+0000",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRReE1UUTBOVFExTnpRd05UQTZNVFExTlRreE9EQTFNUT09",
#       "before": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRReE1UUTBOVFExTnpRd05UQTZNVFExTlRreE9EQTFNUT09"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "56381779049",
#        "category": "Food/Beverages",
#        "name": "Pepsi"
#       },
#       "like_count": 0,
#       "can_remove": false,
#       "user_likes": false,
#       "created_time": "2016-02-19T21:40:50+0000",
#       "id": "10154113675519050_10154114454574050",
#       "message": "We hear you! Please reach out to our friends at customer service by filling out this form: http://pep.si/mQYUEO"
#      }
#     ]
#    },
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T13:56:20+0000",
#    "message": "I've bought different cases of pepsi from different stores, lately I've had atleast 2-3 cans per box that are flat or punctured,  WHAT IS GOING ON?!",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "10203854265101308",
#     "name": "Tamara Tanner"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154113669279050",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113669279050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113669279050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T13:53:01+0000",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T13:53:01+0000",
#    "message": "in regard to you \"recipe sweepstakes\" maybe you should pay some attention to it...hasn't worked in days...DAYS!. Can't put a birthdate in and if you can get one to work it says you already entered....seems a big company like you would be AWARE of your promotions and how they are working...",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "207192029410838",
#     "category": "Company",
#     "name": "MLive Media Group"
#    },
#    "type": "link",
#    "name": "Pepsi Preps Global Emoji Can and Bottle Campaign",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQDwE2J4rWqABtQL&w=130&h=130&url=http%3A%2F%2Fgaia.adage.com%2Fimages%2Fbin%2Fimage%2Fx-large%2FCanadaPepsi201602183X2.jpg&cfs=1",
#    "id": "56381779049_10154113576714050",
#    "caption": "adage.com",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113576714050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154113576714050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T12:52:59+0000",
#    "link": "http://adage.com/article/cmo-strategy/pepsi-preps-global-emoji-bottle-campaign/302748/",
#    "message_tags": {
#     "0": [
#      {
#       "id": "339150749455906",
#       "type": "page",
#       "name": "Pepsi",
#       "length": 5,
#       "offset": 0
#      }
#     ]
#    },
#    "to": {
#     "data": [
#      {
#       "id": "339150749455906",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T12:52:59+0000",
#    "description": "Pepsi is unleashing a global campaign that includes putting custom-designed emojis on cans and bottles.",
#    "message": "Pepsi to go after the \"share a Coke\" campaign",
#    "is_expired": false,
#    "status_type": "shared_story"
#   },
#   {
#    "from": {
#     "id": "10152919265144344",
#     "name": "Monica Lynne Bernatowicz"
#    },
#    "type": "status",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "id": "56381779049_10154112769674050",
#    "likes": {
#     "paging": {
#      "cursors": {
#       "after": "NjIzMDA2MTg3ODExNTUx",
#       "before": "Mzg5Mjc2MDY0NTQ4MDE1"
#      }
#     },
#     "data": [
#      {
#       "id": "389276064548015",
#       "name": "Chris Gardner"
#      },
#      {
#       "id": "10205397063540058",
#       "name": "David Zimdars"
#      },
#      {
#       "id": "623006187811551",
#       "name": "Bob Westcot"
#      }
#     ]
#    },
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154112769674050",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10154112769674050",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T15:12:27+0000",
#    "comments": {
#     "paging": {
#      "cursors": {
#       "after": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRReE1UTTNPVGcyTnprd05UQTZNVFExTlRnNU5EYzBOdz09",
#       "before": "WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRReE1UTTNPVGcyTnprd05UQTZNVFExTlRnNU5EYzBOdz09"
#      }
#     },
#     "data": [
#      {
#       "from": {
#        "id": "10205397063540058",
#        "name": "David Zimdars"
#       },
#       "like_count": 1,
#       "can_remove": false,
#       "user_likes": false,
#       "created_time": "2016-02-19T15:12:27+0000",
#       "id": "10154112769674050_10154113798679050",
#       "message": ""
#      }
#     ]
#    },
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "created_time": "2016-02-19T02:52:02+0000",
#    "message": "I have been a loyal Diet Pepsi drinker for years...decades... Used to drink a 2-liter bottle a day without blinking an eye. Now I can't choke down a 20oz bottle. The new formula is horrible! I might need to start drinking Diet Coke.",
#    "is_expired": false,
#    "status_type": "wall_post"
#   },
#   {
#    "from": {
#     "id": "10203588688016274",
#     "name": "Laura Lynn Morales"
#    },
#    "type": "link",
#    "name": "Click here to support help me get to New York by Laura Lynn Morales",
#    "privacy": {
#     "friends": "",
#     "description": "",
#     "deny": "",
#     "allow": "",
#     "value": ""
#    },
#    "icon": "https://www.facebook.com/images/icons/post.gif",
#    "picture": "https://external.xx.fbcdn.net/safe_image.php?d=AQAWI0xtXcLedAeL&w=130&h=130&url=http%3A%2F%2Ffunds.gfmcdn.com%2F9064365_1455331254.2342.jpg&cfs=1&sx=26&sy=0&sw=400&sh=400",
#    "id": "56381779049_10206965135065340",
#    "caption": "gofundme.com",
#    "is_hidden": false,
#    "actions": [
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10206965135065340",
#      "name": "Comment"
#     },
#     {
#      "link": "https://www.facebook.com/56381779049/posts/10206965135065340",
#      "name": "Like"
#     }
#    ],
#    "updated_time": "2016-02-19T02:04:35+0000",
#    "link": "https://www.gofundme.com/AdriannaMorales",
#    "story": "Laura Lynn Morales shared a link to Pepsi's Timeline.",
#    "to": {
#     "data": [
#      {
#       "id": "56381779049",
#       "category": "Food/Beverages",
#       "name": "Pepsi"
#      }
#     ]
#    },
#    "story_tags": {
#     "36": [
#      {
#       "id": "56381779049",
#       "type": "page",
#       "name": "Pepsi",
#       "length": 5,
#       "offset": 36
#      }
#     ],
#     "0": [
#      {
#       "id": "10203588688016274",
#       "type": "user",
#       "name": "Laura Lynn Morales",
#       "length": 18,
#       "offset": 0
#      }
#     ]
#    },
#    "created_time": "2016-02-19T02:04:35+0000",
#    "description": "I have been nominated to go to the National Youth Leadership Forum for Digital media, Film & Journalism in New York City. I will be in New York for a week and three of the days I will be spending three action packed days on site at the New York Film Academy. This will be a great opportunity  for...",
#    "is_expired": false,
#    "status_type": "shared_story"
#   }
#  ]
# }
# {
#  "data": []
# }
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-25-aaa8045b584f> in <module>()
#       2 pp(g.get_connections(pepsi_id, 'links'))
#       3
# ----> 4 pp(g.get_connections(coke_id, 'feed'))
#       5 pp(g.get_connections(coke_id, 'links'))
#
# /usr/local/lib/python3.5/site-packages/facebook_sdk-1.0.0a0-py3.5.egg/facebook/__init__.py in get_connections(self, id, connection_name, **args)
#     119         """Fetches the connections for given object."""
#     120         return self.request(
# --> 121             "%s/%s/%s" % (self.version, id, connection_name), args)
#     122
#     123     def put_object(self, parent_object, connection_name, **data):
#
# /usr/local/lib/python3.5/site-packages/facebook_sdk-1.0.0a0-py3.5.egg/facebook/__init__.py in request(self, path, args, post_args, files, method)
#     270                 raise GraphAPIError(response.json())
#     271         else:
# --> 272             raise GraphAPIError('Maintype was not text, image, or querystring')
#     273
#     274         if result and isinstance(result, dict) and result.get("error"):
#
# GraphAPIError: Maintype was not text, image, or querystring

# %% [markdown]
# ## Example 7. Querying for all of your friends' likes

# %%
# First, let's query for all of the likes in your social
# network and store them in a slightly more convenient
# data structure as a dictionary keyed on each friend's
# name. We'll use a dictionary comprehension to iterate
# over the friends and build up the likes in an intuitive
# way, although the new "field expansion" feature could 
# technically do the job in one fell swoop as follows:
#
# g.get_object('me', fields='id,name,friends.fields(id,name,likes)')
#
# See Appendix C for more information on Python tips such as
# dictionary comprehensions

friends = g.get_connections("me", "likes")['data']
print(friends)

likes = { friend['name'] : g.get_connections(friend['id'], "likes")['data'] 
          for friend in friends }

print(likes)
# Out:
# [{'created_time': '2015-12-14T22:45:20+0000', 'id': '258047497615489', 'category': 'Athlete', 'name': 'Narmin Assria IFBB Bikini Pro'}, {'created_time': '2015-12-14T22:45:10+0000', 'id': '124500284255091', 'category': 'Athlete', 'name': 'Felice Herrig fan page'}, {'created_time': '2015-06-21T19:25:46+0000', 'id': '556264724526931', 'category': 'Community', 'name': 'Cung Hoàng Đạo'}, {'created_time': '2014-12-10T16:01:39+0000', 'id': '239209922765678', 'category': 'Athlete', 'name': 'Christina Vargas'}, {'created_time': '2014-11-19T18:39:36+0000', 'id': '147170835314482', 'category': 'Public Figure', 'name': 'Emily Skye'}, {'created_time': '2014-11-18T12:42:25+0000', 'id': '449997995096836', 'category': 'Entertainer', 'name': 'CLARA'}, {'created_time': '2014-11-18T12:41:40+0000', 'id': '288596241260375', 'category': 'Athlete', 'name': 'Paige Hathaway'}, {'created_time': '2014-11-18T00:13:37+0000', 'id': '181712638644349', 'category': 'Software', 'name': 'The Xen Project'}, {'created_time': '2014-10-28T08:45:29+0000', 'id': '187030591324147', 'category': 'Product/Service', 'name': 'TurnKey GNU/Linux'}, {'created_time': '2014-10-24T03:29:59+0000', 'id': '406433779383', 'category': 'Entertainer', 'name': 'Dwayne The Rock Johnson'}, {'created_time': '2014-08-26T01:54:25+0000', 'id': '67920382572', 'category': 'Sports Team', 'name': 'Liverpool FC'}, {'created_time': '2014-08-26T01:54:21+0000', 'id': '19034719952', 'category': 'Sports Team', 'name': 'Real Madrid C.F.'}, {'created_time': '2014-08-26T01:54:18+0000', 'id': '197394889304', 'category': 'Sports Team', 'name': 'FC Barcelona'}, {'created_time': '2014-08-26T01:54:10+0000', 'id': '7724542745', 'category': 'Sports Team', 'name': 'Manchester United'}, {'created_time': '2014-08-26T01:51:41+0000', 'id': '5565627823', 'category': 'Musician/Band', 'name': 'Christina Aguilera'}, {'created_time': '2014-08-26T01:51:13+0000', 'id': '28940545600', 'category': 'Musician/Band', 'name': 'Beyoncé'}, {'created_time': '2014-08-26T01:51:00+0000', 'id': '112525015425778', 'category': 'Musician/Band', 'name': 'Paul McCartney'}, {'created_time': '2014-08-26T01:50:51+0000', 'id': '8210451787', 'category': 'Musician/Band', 'name': 'Linkin Park'}, {'created_time': '2014-08-26T01:50:44+0000', 'id': '5413509299', 'category': 'Musician/Band', 'name': 'Avril Lavigne'}, {'created_time': '2014-08-26T01:50:36+0000', 'id': '19691681472', 'category': 'Musician/Band', 'name': 'Michael Jackson'}, {'created_time': '2014-08-26T01:50:33+0000', 'id': '67253243887', 'category': 'Musician/Band', 'name': 'Justin Bieber'}, {'created_time': '2014-08-26T01:50:32+0000', 'id': '45309870078', 'category': 'Musician/Band', 'name': 'Eminem'}, {'created_time': '2012-02-14T00:07:37+0000', 'id': '131479102555', 'category': 'Software', 'name': 'OpenNebula'}, {'created_time': '2011-08-26T00:38:56+0000', 'id': '181876955215025', 'category': 'Personal Blog', 'name': 'Steve Jobs & The Sound of Silence'}, {'created_time': '2011-08-23T10:14:34+0000', 'id': '170608109645542', 'category': 'Company', 'name': 'findertrip.com', 'category_list': [{'id': '2200', 'name': 'Company'}]}]
# {'Liverpool FC': [{'id': '693116264158242', 'category': 'Sports League', 'name': 'Australian Football Legends'}, {'id': '1411122042516798', 'category': 'Community', 'name': 'The Global Goals'}, {'id': '388758574542339', 'category': 'Company', 'name': 'Marathonbet'}, {'id': '1469095813339946', 'category': 'Athlete', 'name': 'Adam Lallana'}, {'id': '412220902242810', 'category': 'Cars', 'name': 'Vauxhall Liverpool FC'}, {'id': '504997576203914', 'category': 'Local Business', 'name': "Dunkin' Donuts"}, {'id': '44663724981', 'category': 'Retail and Consumer Merchandise', 'name': 'Lumber Liquidators', 'category_list': [{'id': '191328180890797', 'name': 'Carpet & Flooring Store'}, {'id': '192647794097278', 'name': 'Home Decor'}]}, {'id': '195630897239121', 'category': 'Community', 'name': 'The Unofficial Liverpool Football Club Museum'}, {'id': '129184980468234', 'category': 'Product/Service', 'name': 'Konica Minolta Business Solutions UK Ltd'}, {'id': '554523744587147', 'category': 'Automotive', 'name': 'Lloyds Autobody', 'category_list': [{'id': '188462984509706', 'name': 'Auto Body Shop'}]}, {'id': '549534718410598', 'category': 'Community', 'name': 'The David Cahill Rehabilitation Fund'}, {'id': '199143160180798', 'category': 'Community Organization', 'name': 'Homebaked Anfield', 'category_list': [{'id': '152880021441864', 'name': 'Community Organization'}, {'id': '1578263382424714', 'name': 'Place to Eat/Drink'}]}, {'id': '381975795195836', 'category': 'Public Figure', 'name': 'Mighty Red'}, {'id': '292209990897095', 'category': 'Cause', 'name': 'Hillsborough Family Support Group'}, {'id': '102342599906776', 'category': 'Cars', 'name': 'Chevrolet FC'}, {'id': '246922408759790', 'category': 'Community', 'name': 'Liverpool FC LGBT Supporters'}, {'id': '495599857123730', 'category': 'Community', 'name': "Liverpool FC Supporters' Committee"}, {'id': '137465474851', 'category': 'Travel/Leisure', 'name': 'Thomas Cook Sport'}, {'id': '190562337647505', 'category': 'Clothing', 'name': 'Ramsey'}, {'id': '110172992388544', 'category': 'Travel/Leisure', 'name': 'Buccament Bay Resort', 'category_list': [{'id': '199734546726648', 'name': 'Beach Resort'}, {'id': '164243073639257', 'name': 'Hotel'}]}, {'id': '164300150342893', 'category': 'App Page', 'name': 'Liverpool FC Fantasy Manager'}, {'id': '111518968939562', 'category': 'Community', 'name': "it's liverpool"}, {'id': '9401782383', 'category': 'Food/Beverages', 'name': 'Carlsberg', 'category_list': [{'id': '2252', 'name': 'Food/Beverages'}]}, {'id': '155725841111588', 'category': 'Bank/Financial Institution', 'name': 'Standard Chartered'}, {'id': '120904874592612', 'category': 'Website', 'name': '188BET'}], 'Paul McCartney': [], 'Emily Skye': [{'id': '326051175949', 'category': 'Magazine', 'name': 'SHAPE Magazine Australia'}, {'id': '144228292427', 'category': 'Tours/Sightseeing', 'name': 'Liberty Helicopters', 'category_list': [{'id': '175657495818161', 'name': 'Tour Guide'}]}, {'id': '141845322616', 'category': 'Health/Medical/Pharmaceuticals', 'name': 'Good Price Pharmacy Warehouse'}, {'id': '304144409694066', 'category': 'Local Business', 'name': 'My Fit Foods West Hollywood', 'category_list': [{'id': '198722103478014', 'name': 'Health Food Store'}]}, {'id': '266975950082039', 'category': 'Actor/Director', 'name': 'Nina Dobrev'}, {'id': '108196899960', 'category': 'Media/News/Publishing', 'name': 'myGC', 'category_list': [{'id': '169056916473899', 'name': 'Broadcasting & Media Production'}]}, {'id': '10956839700', 'category': 'Media/News/Publishing', 'name': '1029 Hot Tomato', 'category_list': [{'id': '2233', 'name': 'Media/News/Publishing'}]}, {'id': '340804309431946', 'category': 'Product/Service', 'name': "Let's Get Funked Up"}, {'id': '607178809314950', 'category': 'Actor/Director', 'name': 'Curtis Lepore'}, {'id': '632404633503433', 'category': 'Actor/Director', 'name': 'Claire Holt'}, {'id': '1504111519888009', 'category': 'Entertainer', 'name': 'J. Waltz'}, {'id': '5075693326 ...

# %% [markdown]
# ## Example 8. Calculating the most popular likes among your friends

# %%
# Analyze all likes from friendships for frequency

# pip install prettytable
from prettytable import PrettyTable
from collections import Counter
friends_likes = Counter([like['name']
                         for friend in likes 
                           for like in likes[friend]
                               if like.get('name')])

pt = PrettyTable(field_names=['Name', 'Freq'])
pt.align['Name'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(fl) for fl in friends_likes.most_common(10) ]

print('Top 10 likes amongst friends')
print(pt)
# Out:
# Top 10 likes amongst friends
# +------------------------------------+------+
# | Name                               | Freq |
# +------------------------------------+------+
# | Arvin Lal                          |    2 |
# | Dwayne The Rock Johnson            |    2 |
# | Tyler the Creator                  |    2 |
# | Chevrolet FC                       |    2 |
# | City of Hope                       |    1 |
# | Ten Second Songs                   |    1 |
# | Melt Pilates & Hot Yoga            |    1 |
# | Emirates                           |    1 |
# | Kelly Davis - Fit Family Lifestyle |    1 |
# | LP Recharge                        |    1 |
# +------------------------------------+------+

# %% [markdown]
# ## Example 9. Calculating the most popular categories for likes among your friends

# %%
# Analyze all like categories by frequency

friends_likes_categories = Counter([like['category'] 
                                    for friend in likes 
                                      for like in likes[friend]])

pt = PrettyTable(field_names=['Category', 'Freq'])
pt.align['Category'], pt.align['Freq'] = 'l', 'r'
[ pt.add_row(flc) for flc in friends_likes_categories.most_common(10) ]

print("Top 10 like categories for friends")
print(pt)
# Out:
# Top 10 like categories for friends
# +-------------------------+------+
# | Category                | Freq |
# +-------------------------+------+
# | Athlete                 |   53 |
# | Musician/Band           |   19 |
# | Travel/Leisure          |   15 |
# | Non-Profit Organization |   15 |
# | Company                 |   13 |
# | Movie                   |   12 |
# | Food/Beverages          |   10 |
# | Product/Service         |   10 |
# | Local Business          |   10 |
# | Community               |   10 |
# +-------------------------+------+

# %% [markdown]
# ## Example 10. Calculating the number of likes for each friend and sorting by frequency

# %%
# Build a frequency distribution of number of likes by 
# friend with a dictionary comprehension and sort it in 
# descending order

from operator import itemgetter

num_likes_by_friend = { friend : len(likes[friend]) 
                        for friend in likes }


pt = PrettyTable(field_names=['Friend', 'Num Likes'])
pt.align['Friend'], pt.align['Num Likes'] = 'l', 'r'
[ pt.add_row(nlbf) 
  for nlbf in sorted(num_likes_by_friend.items(), 
                     key=itemgetter(1), 
                     reverse=True) ]

print("Number of likes per friend")
print(pt)
# Out:
# Number of likes per friend
# +-----------------------------------+-----------+
# | Friend                            | Num Likes |
# +-----------------------------------+-----------+
# | Liverpool FC                      |        25 |
# | findertrip.com                    |        25 |
# | Real Madrid C.F.                  |        25 |
# | Manchester United                 |        25 |
# | Justin Bieber                     |        25 |
# | Christina Vargas                  |        25 |
# | Linkin Park                       |        25 |
# | Felice Herrig fan page            |        25 |
# | Emily Skye                        |        25 |
# | FC Barcelona                      |        24 |
# | Narmin Assria IFBB Bikini Pro     |        22 |
# | Dwayne The Rock Johnson           |        19 |
# | Eminem                            |         9 |
# | Paige Hathaway                    |         7 |
# | Beyoncé                           |         6 |
# | Avril Lavigne                     |         4 |
# | Michael Jackson                   |         2 |
# | Christina Aguilera                |         1 |
# | Paul McCartney                    |         0 |
# | Cung Hoàng Đạo                    |         0 |
# | OpenNebula                        |         0 |
# | TurnKey GNU/Linux                 |         0 |
# | CLARA                             |         0 |
# | The Xen Project                   |         0 |
# | Steve Jobs & The Sound of Silence |         0 |
# +-----------------------------------+-----------+

# %% [markdown]
# ## Example 11. Finding common likes between an ego and its friendships in a social network

# %%
# Which of your likes are in common with which friends?
my_likes = [ like['name'] 
             for like in g.get_connections("me", "likes")['data'] ]

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((ml,)) for ml in my_likes ]
print("My likes")
print(pt)

# Use the set intersection as represented by the ampersand
# operator to find common likes.

common_likes = list(set(my_likes) & set(friends_likes))

pt = PrettyTable(field_names=["Name"])
pt.align = 'l'
[ pt.add_row((cl,)) for cl in common_likes ]
print("My common likes with friends")
print(pt)
# Out:
# My likes
# +-----------------------------------+
# | Name                              |
# +-----------------------------------+
# | Narmin Assria IFBB Bikini Pro     |
# | Felice Herrig fan page            |
# | Cung Hoàng Đạo                    |
# | Christina Vargas                  |
# | Emily Skye                        |
# | CLARA                             |
# | Paige Hathaway                    |
# | The Xen Project                   |
# | TurnKey GNU/Linux                 |
# | Dwayne The Rock Johnson           |
# | Liverpool FC                      |
# | Real Madrid C.F.                  |
# | FC Barcelona                      |
# | Manchester United                 |
# | Christina Aguilera                |
# | Beyoncé                           |
# | Paul McCartney                    |
# | Linkin Park                       |
# | Avril Lavigne                     |
# | Michael Jackson                   |
# | Justin Bieber                     |
# | Eminem                            |
# | OpenNebula                        |
# | Steve Jobs & The Sound of Silence |
# | findertrip.com                    |
# +-----------------------------------+
# My common likes with friends
# +-------------------------+
# | Name                    |
# +-------------------------+
# | Dwayne The Rock Johnson |
# +-------------------------+

# %% [markdown]
# ## Example 12. Calculating the friends most similar to an ego in a social network

# %%
# Which of your friends like things that you like?

similar_friends = [ (friend, friend_like['name']) 
                     for friend, friend_likes in likes.items()
                       for friend_like in friend_likes
                         if friend_like.get('name') in common_likes ]


# Filter out any possible duplicates that could occur

ranked_friends = Counter([ friend for (friend, like) in list(set(similar_friends)) ])


pt = PrettyTable(field_names=["Friend", "Common Likes"])
pt.align["Friend"], pt.align["Common Likes"] = 'l', 'r'
[ pt.add_row(rf) 
  for rf in sorted(ranked_friends.items(), 
                   key=itemgetter(1), 
                   reverse=True) ]
print("My similar friends (ranked)")
print(pt)

# Also keep in mind that you have the full range of plotting
# capabilities available to you. A quick histogram that shows
# how many friends.

plt.hist([value for value in ranked_friends.values()])
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')

# Keep in mind that you can customize the binning
# as desired. See http://matplotlib.org/api/pyplot_api.html

# For example...
print(ranked_friends.values())
plt.figure() # Display the previous plot
plt.hist([value for value in ranked_friends.values()],)
plt.xlabel('Bins (number of friends with shared likes)')
plt.ylabel('Number of shared likes in each bin')
plt.figure() # Display the working plot
# Out:
# My similar friends (ranked)
# +-------------------------------+--------------+
# | Friend                        | Common Likes |
# +-------------------------------+--------------+
# | Christina Vargas              |            1 |
# | Narmin Assria IFBB Bikini Pro |            1 |
# +-------------------------------+--------------+
# dict_values([1, 1])

# %% [markdown]
# ## Example 13. Constructing a graph of mutual friendships

# %%
import networkx as nx # pip install networkx
import requests # pip install requests

friends = [ (friend['id'], friend['name'],)
                for friend in g.get_connections('me', 'friends')['data'] ]

url = 'https://graph.facebook.com/me/mutualfriends/%s?access_token=%s'

mutual_friends = {} 

# This loop spawns a separate request for each iteration, so
# it may take a while. Optimization with a thread pool or similar
# technique would be possible.
for friend_id, friend_name in friends:
    r = requests.get(url % (friend_id, ACCESS_TOKEN,) )
    response_data = json.loads(r.content)['data']
    mutual_friends[friend_name] = [ data['name'] 
                                    for data in response_data ]
    
nxg = nx.Graph()

[ nxg.add_edge('me', mf) for mf in mutual_friends ]

[ nxg.add_edge(f1, f2) 
  for f1 in mutual_friends 
      for f2 in mutual_friends[f1] ]

# Explore what's possible to do with the graph by 
# typing nxg.<tab> or executing a new cell with 
# the following value in it to see some pydoc on nxg
print(nxg)

# %% [markdown]
# ## Example 14. Finding and analyzing cliques in a graph of mutual friendships

# %%
# Finding cliques is a hard problem, so this could
# take a while for large graphs.
# See http://en.wikipedia.org/wiki/NP-complete and 
# http://en.wikipedia.org/wiki/Clique_problem.

cliques = [c for c in nx.find_cliques(nxg)]

num_cliques = len(cliques)

clique_sizes = [len(c) for c in cliques]
max_clique_size = clique_sizes.count
avg_clique_size = sum(clique_sizes) / num_cliques

max_cliques = [c for c in cliques if len(c) == max_clique_size]

num_max_cliques = len(max_cliques)

max_clique_sets = [set(c) for c in max_cliques]
friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
                                  max_clique_sets))

print('Num cliques:', num_cliques)
print('Avg clique size:', avg_clique_size)
print('Max clique size:', max_clique_size)
print('Num max cliques:', num_max_cliques)
print('Friends in all max cliques:')
print(json.dumps(friends_in_all_max_cliques, indent=1))
print('Max cliques:')
print(json.dumps(max_cliques, indent=1))
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:12: RuntimeWarning: invalid value encountered in double_scalars
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-7df8a91ef55a> in <module>()
#      17
#      18 max_clique_sets = [set(c) for c in max_cliques]
# ---> 19 friends_in_all_max_cliques = list(reduce(lambda x, y: x.intersection(y),
#      20                                   max_clique_sets))
#      21
#
# NameError: name 'reduce' is not defined

# %% [markdown]
# ## Example 15. Serializing a NetworkX graph to a file for consumption by D3

# %%
from networkx.readwrite import json_graph

nld = json_graph.node_link_data(nxg)

json.dump(nld, open('resources/ch02-facebook/viz/force.json','w'))

# %% [markdown]
# Note: You may need to implement some filtering on the NetworkX graph before writing it out to a file for display in D3, and for more than dozens of nodes, it may not be reasonable to render a meaningful visualization without some JavaScript hacking on its parameters. View the JavaScript source in [force.html](files/resources/ch02-facebook/viz/force.html) for some of the details.

# %% [markdown]
# ## Example 16. Visualizing a mutual friendship graph with D3

# %%
from IPython.display import IFrame
from IPython.core.display import display

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix.

viz_file = 'files/resources/ch02-facebook/viz/force.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="files/resources/ch02-facebook/viz/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
