# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = '8J4ChDgB4TENiLeO2gXcmQGzK'
CONSUMER_SECRET ='wQBzpNpqgKzwk1gCItcJ30270dzJiAgQHv6n9QcF5f4KoodGgg'
OAUTH_TOKEN = '23399092-hPluWow97IVPNenB3ycbAbklvv8i9CyRfVvtnBjxz'
OAUTH_TOKEN_SECRET = 'EJ7GOsacvmZsDikgPzAaoSbw7SWYV1I4dzv2y5EcVzjil'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x105267898>

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
print(us_trends)
# Out:
# [{'trends': [{'name': '#canseliçinsusma', 'url': 'http://twitter.com/search?q=%23canseli%C3%A7insusma', 'tweet_volume': 264646, 'query': '%23canseli%C3%A7insusma', 'promoted_content': None}, {'name': '#SupportToHarry', 'url': 'http://twitter.com/search?q=%23SupportToHarry', 'tweet_volume': 159240, 'query': '%23SupportToHarry', 'promoted_content': None}, {'name': '#FashionVictims', 'url': 'http://twitter.com/search?q=%23FashionVictims', 'tweet_volume': 123001, 'query': '%23FashionVictims', 'promoted_content': None}, {'name': '#DBT7GHVIP', 'url': 'http://twitter.com/search?q=%23DBT7GHVIP', 'tweet_volume': 49251, 'query': '%23DBT7GHVIP', 'promoted_content': None}, {'name': 'Anthony Davis', 'url': 'http://twitter.com/search?q=%22Anthony+Davis%22', 'tweet_volume': 52569, 'query': '%22Anthony+Davis%22', 'promoted_content': None}, {'name': '#DAYTONA500', 'url': 'http://twitter.com/search?q=%23DAYTONA500', 'tweet_volume': 360909, 'query': '%23DAYTONA500', 'promoted_content': None}, {'name': 'Faustão', 'url': 'http://twitter.com/search?q=Faust%C3%A3o', 'tweet_volume': 10228, 'query': 'Faust%C3%A3o', 'promoted_content': None}, {'name': 'Vilouta', 'url': 'http://twitter.com/search?q=Vilouta', 'tweet_volume': 16800, 'query': 'Vilouta', 'promoted_content': None}, {'name': 'Márcio Araújo', 'url': 'http://twitter.com/search?q=%22M%C3%A1rcio+Ara%C3%BAjo%22', 'tweet_volume': 11057, 'query': '%22M%C3%A1rcio+Ara%C3%BAjo%22', 'promoted_content': None}, {'name': 'LALI EN LATEN', 'url': 'http://twitter.com/search?q=%22LALI+EN+LATEN%22', 'tweet_volume': 13207, 'query': '%22LALI+EN+LATEN%22', 'promoted_content': None}, {'name': 'EU AMO SER HUNTER', 'url': 'http://twitter.com/search?q=%22EU+AMO+SER+HUNTER%22', 'tweet_volume': 35061, 'query': '%22EU+AMO+SER+HUNTER%22', 'promoted_content': None}, {'name': 'Licha', 'url': 'http://twitter.com/search?q=Licha', 'tweet_volume': 13096, 'query': 'Licha', 'promoted_content': None}, {'name': 'JESUS IS COMING', 'url': 'http://twitter.com/search?q=%22JESUS+IS+COMING%22', 'tweet_volume': None, 'query': '%22JESUS+IS+COMING%22', 'promoted_content': None}, {'name': '猫の日', 'url': 'http://twitter.com/search?q=%E7%8C%AB%E3%81%AE%E6%97%A5', 'tweet_volume': 122159, 'query': '%E7%8C%AB%E3%81%AE%E6%97%A5', 'promoted_content': None}, {'name': 'Bolivia', 'url': 'http://twitter.com/search?q=Bolivia', 'tweet_volume': 82335, 'query': 'Bolivia', 'promoted_content': None}, {'name': 'Dante Palma', 'url': 'http://twitter.com/search?q=%22Dante+Palma%22', 'tweet_volume': None, 'query': '%22Dante+Palma%22', 'promoted_content': None}, {'name': 'Salih Dursun', 'url': 'http://twitter.com/search?q=%22Salih+Dursun%22', 'tweet_volume': 165813, 'query': '%22Salih+Dursun%22', 'promoted_content': None}, {'name': 'Dion Waiters', 'url': 'http://twitter.com/search?q=%22Dion+Waiters%22', 'tweet_volume': 13259, 'query': '%22Dion+Waiters%22', 'promoted_content': None}, {'name': 'Rodriguinho', 'url': 'http://twitter.com/search?q=Rodriguinho', 'tweet_volume': None, 'query': 'Rodriguinho', 'promoted_content': None}, {'name': 'De Paul', 'url': 'http://twitter.com/search?q=%22De+Paul%22', 'tweet_volume': None, 'query': '%22De+Paul%22', 'promoted_content': None}, {'name': 'Fernández', 'url': 'http://twitter.com/search?q=Fern%C3%A1ndez', 'tweet_volume': 32021, 'query': 'Fern%C3%A1ndez', 'promoted_content': None}, {'name': '#نطالب_باعفاء_وزير_التعليم', 'url': 'http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85', 'tweet_volume': None, 'query': '%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85', 'promoted_content': None}, {'name': '#VemSeguidoresClubeSDV', 'url': 'http://twitter.com/search?q=%23VemSeguidoresClubeSDV', 'tweet_volume': None, 'query': '%23VemSeguidoresClubeSDV', 'promoted_content': None}, {'name': '#GalaDragLPGC', 'url': 'http://twitter.com/sear ...
# [{'trends': [{'name': 'Anthony Davis', 'url': 'http://twitter.com/search?q=%22Anthony+Davis%22', 'tweet_volume': 51423, 'query': '%22Anthony+Davis%22', 'promoted_content': None}, {'name': '#DAYTONA500', 'url': 'http://twitter.com/search?q=%23DAYTONA500', 'tweet_volume': 360514, 'query': '%23DAYTONA500', 'promoted_content': None}, {'name': 'Dion Waiters', 'url': 'http://twitter.com/search?q=%22Dion+Waiters%22', 'tweet_volume': 13162, 'query': '%22Dion+Waiters%22', 'promoted_content': None}, {'name': '#StadiumSeries', 'url': 'http://twitter.com/search?q=%23StadiumSeries', 'tweet_volume': 33367, 'query': '%23StadiumSeries', 'promoted_content': None}, {'name': '#UFCPittsburgh', 'url': 'http://twitter.com/search?q=%23UFCPittsburgh', 'tweet_volume': 11839, 'query': '%23UFCPittsburgh', 'promoted_content': None}, {'name': '#USAvCAN', 'url': 'http://twitter.com/search?q=%23USAvCAN', 'tweet_volume': 10620, 'query': '%23USAvCAN', 'promoted_content': None}, {'name': '#SupportToHarry', 'url': 'http://twitter.com/search?q=%23SupportToHarry', 'tweet_volume': 156686, 'query': '%23SupportToHarry', 'promoted_content': None}, {'name': 'Sam Pepper', 'url': 'http://twitter.com/search?q=%22Sam+Pepper%22', 'tweet_volume': 23319, 'query': '%22Sam+Pepper%22', 'promoted_content': None}, {'name': 'Bubba Watson', 'url': 'http://twitter.com/search?q=%22Bubba+Watson%22', 'tweet_volume': None, 'query': '%22Bubba+Watson%22', 'promoted_content': None}, {'name': 'Richard Jefferson', 'url': 'http://twitter.com/search?q=%22Richard+Jefferson%22', 'tweet_volume': None, 'query': '%22Richard+Jefferson%22', 'promoted_content': None}, {'name': 'Drummond', 'url': 'http://twitter.com/search?q=Drummond', 'tweet_volume': None, 'query': 'Drummond', 'promoted_content': None}, {'name': 'Zucker', 'url': 'http://twitter.com/search?q=Zucker', 'tweet_volume': None, 'query': 'Zucker', 'promoted_content': None}, {'name': 'Steven Adams', 'url': 'http://twitter.com/search?q=%22Steven+Adams%22', 'tweet_volume': None, 'query': '%22Steven+Adams%22', 'promoted_content': None}, {'name': 'Rozsival', 'url': 'http://twitter.com/search?q=Rozsival', 'tweet_volume': None, 'query': 'Rozsival', 'promoted_content': None}, {'name': 'Megabus', 'url': 'http://twitter.com/search?q=Megabus', 'tweet_volume': None, 'query': 'Megabus', 'promoted_content': None}, {'name': 'Pahrump', 'url': 'http://twitter.com/search?q=Pahrump', 'tweet_volume': None, 'query': 'Pahrump', 'promoted_content': None}, {'name': 'SWEN LOVE JMO', 'url': 'http://twitter.com/search?q=%22SWEN+LOVE+JMO%22', 'tweet_volume': None, 'query': '%22SWEN+LOVE+JMO%22', 'promoted_content': None}, {'name': 'Ibaka', 'url': 'http://twitter.com/search?q=Ibaka', 'tweet_volume': None, 'query': 'Ibaka', 'promoted_content': None}, {'name': 'Kyle Anderson', 'url': 'http://twitter.com/search?q=%22Kyle+Anderson%22', 'tweet_volume': None, 'query': '%22Kyle+Anderson%22', 'promoted_content': None}, {'name': 'Tancredi', 'url': 'http://twitter.com/search?q=Tancredi', 'tweet_volume': None, 'query': 'Tancredi', 'promoted_content': None}, {'name': 'Mark Sertich', 'url': 'http://twitter.com/search?q=%22Mark+Sertich%22', 'tweet_volume': None, 'query': '%22Mark+Sertich%22', 'promoted_content': None}, {'name': 'Hubie Brown', 'url': 'http://twitter.com/search?q=%22Hubie+Brown%22', 'tweet_volume': None, 'query': '%22Hubie+Brown%22', 'promoted_content': None}, {'name': '#YouStartedItWhen', 'url': 'http://twitter.com/search?q=%23YouStartedItWhen', 'tweet_volume': None, 'query': '%23YouStartedItWhen', 'promoted_content': None}, {'name': '#WWEFastlane', 'url': 'http://twitter.com/search?q=%23WWEFastlane', 'tweet_volume': 38190, 'query': '%23WWEFastlane', 'promoted_content': None}, {'name': '#SundayFunday', 'url': 'http://twitter.com/search?q=%23SundayFunday', 'tweet_volume': 25262, 'query': '%23SundayFunday', 'promoted_content': None}, {'name': '#PhotographCover', 'url': 'http://twitter.com/search?q=%23PhotographCover', 'tweet_volume': 28887, 'query': '%23PhotographCover', ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#canseli\u00e7insusma",
#     "url": "http://twitter.com/search?q=%23canseli%C3%A7insusma",
#     "tweet_volume": 264646,
#     "query": "%23canseli%C3%A7insusma",
#     "promoted_content": null
#    },
#    {
#     "name": "#SupportToHarry",
#     "url": "http://twitter.com/search?q=%23SupportToHarry",
#     "tweet_volume": 159240,
#     "query": "%23SupportToHarry",
#     "promoted_content": null
#    },
#    {
#     "name": "#FashionVictims",
#     "url": "http://twitter.com/search?q=%23FashionVictims",
#     "tweet_volume": 123001,
#     "query": "%23FashionVictims",
#     "promoted_content": null
#    },
#    {
#     "name": "#DBT7GHVIP",
#     "url": "http://twitter.com/search?q=%23DBT7GHVIP",
#     "tweet_volume": 49251,
#     "query": "%23DBT7GHVIP",
#     "promoted_content": null
#    },
#    {
#     "name": "Anthony Davis",
#     "url": "http://twitter.com/search?q=%22Anthony+Davis%22",
#     "tweet_volume": 52569,
#     "query": "%22Anthony+Davis%22",
#     "promoted_content": null
#    },
#    {
#     "name": "#DAYTONA500",
#     "url": "http://twitter.com/search?q=%23DAYTONA500",
#     "tweet_volume": 360909,
#     "query": "%23DAYTONA500",
#     "promoted_content": null
#    },
#    {
#     "name": "Faust\u00e3o",
#     "url": "http://twitter.com/search?q=Faust%C3%A3o",
#     "tweet_volume": 10228,
#     "query": "Faust%C3%A3o",
#     "promoted_content": null
#    },
#    {
#     "name": "Vilouta",
#     "url": "http://twitter.com/search?q=Vilouta",
#     "tweet_volume": 16800,
#     "query": "Vilouta",
#     "promoted_content": null
#    },
#    {
#     "name": "M\u00e1rcio Ara\u00fajo",
#     "url": "http://twitter.com/search?q=%22M%C3%A1rcio+Ara%C3%BAjo%22",
#     "tweet_volume": 11057,
#     "query": "%22M%C3%A1rcio+Ara%C3%BAjo%22",
#     "promoted_content": null
#    },
#    {
#     "name": "LALI EN LATEN",
#     "url": "http://twitter.com/search?q=%22LALI+EN+LATEN%22",
#     "tweet_volume": 13207,
#     "query": "%22LALI+EN+LATEN%22",
#     "promoted_content": null
#    },
#    {
#     "name": "EU AMO SER HUNTER",
#     "url": "http://twitter.com/search?q=%22EU+AMO+SER+HUNTER%22",
#     "tweet_volume": 35061,
#     "query": "%22EU+AMO+SER+HUNTER%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Licha",
#     "url": "http://twitter.com/search?q=Licha",
#     "tweet_volume": 13096,
#     "query": "Licha",
#     "promoted_content": null
#    },
#    {
#     "name": "JESUS IS COMING",
#     "url": "http://twitter.com/search?q=%22JESUS+IS+COMING%22",
#     "tweet_volume": null,
#     "query": "%22JESUS+IS+COMING%22",
#     "promoted_content": null
#    },
#    {
#     "name": "\u732b\u306e\u65e5",
#     "url": "http://twitter.com/search?q=%E7%8C%AB%E3%81%AE%E6%97%A5",
#     "tweet_volume": 122159,
#     "query": "%E7%8C%AB%E3%81%AE%E6%97%A5",
#     "promoted_content": null
#    },
#    {
#     "name": "Bolivia",
#     "url": "http://twitter.com/search?q=Bolivia",
#     "tweet_volume": 82335,
#     "query": "Bolivia",
#     "promoted_content": null
#    },
#    {
#     "name": "Dante Palma",
#     "url": "http://twitter.com/search?q=%22Dante+Palma%22",
#     "tweet_volume": null,
#     "query": "%22Dante+Palma%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Salih Dursun",
#     "url": "http://twitter.com/search?q=%22Salih+Dursun%22",
#     "tweet_volume": 165813,
#     "query": "%22Salih+Dursun%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Dion Waiters",
#     "url": "http://twitter.com/search?q=%22Dion+Waiters%22",
#     "tweet_volume": 13259,
#     "query": "%22Dion+Waiters%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Rodriguinho",
#     "url": "http://twitter.com/search?q=Rodriguinho",
#     "tweet_volume": null,
#     "query": "Rodriguinho",
#     "promoted_content": null
#    },
#    {
#     "name": "De Paul",
#     "url": "http://twitter.com/search?q=%22De+Paul%22",
#     "tweet_volume": null,
#     "query": "%22De+Paul%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Fern\u00e1ndez",
#     "url": "http://twitter.com/search?q=Fern%C3%A1ndez",
#     "tweet_volume": 32021,
#     "query": "Fern%C3%A1ndez",
#     "promoted_content": null
#    },
#    {
#     "name": "#\u0646\u0637\u0627\u0644\u0628_\u0628\u0627\u0639\u0641\u0627\u0621_\u0648\u0632\u064a\u0631_\u0627\u0644\u062a\u0639\u0644\u064a\u0645",
#     "url": "http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "tweet_volume": null,
#     "query": "%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D8%B9%D9%81%D8%A7%D8%A1_%D9%88%D8%B2%D9%8A%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D9%84%D9%8A%D9%85",
#     "promoted_content": null
#    },
#    {
#     "name": "#VemSeguidoresClubeSDV",
#     "url": "http://twitter.com/search?q=%23VemSeguidoresClubeSDV",
#     "tweet_volume": null,
#     "query": "%23VemSeguidoresClubeSDV",
#     "promoted_content": null
#    },
#    {
#     "name": "#GalaDragLPGC",
#     "url": "http://twitter.com/search?q=%23GalaDragLPGC",
#     "tweet_volume": 18683,
#     "query": "%23GalaDragLPGC",
#     "promoted_content": null
#    },
#    {
#     "name": "#\u0643\u0644\u0645\u0647_\u0644\u062d\u062f_\u0648\u0627\u062d\u0634\u0643",
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D9%84%D8%AD%D8%AF_%D9%88%D8%A7%D8%AD%D8%B4%D9%83",
#     "tweet_volume": null,
#     "query": "%23%D9%83%D9%84%D9%85%D9%87_%D9%84%D8%AD%D8%AF_%D9%88%D8%A7%D8%AD%D8%B4%D9%83",
#     "promoted_content": null
#    },
#    {
#     "name": "#CuartoMilenio",
#     "url": "http://twitter.com/search?q=%23CuartoMilenio",
#     "tweet_volume": null,
#     "query": "%23CuartoMilenio",
#     "promoted_content": null
#    },
#    {
#     "name": "#MTVAYTOBR",
#     "url": "http://twitter.com/search?q=%23MTVAYTOBR",
#     "tweet_volume": null,
#     "query": "%23MTVAYTOBR",
#     "promoted_content": null
#    },
#    {
#     "name": "#TheNightManager",
#     "url": "http://twitter.com/search?q=%23TheNightManager",
#     "tweet_volume": 16137,
#     "query": "%23TheNightManager",
#     "promoted_content": null
#    },
#    {
#     "name": "#UFCPittsburgh",
#     "url": "http://twitter.com/search?q=%23UFCPittsburgh",
#     "tweet_volume": 12292,
#     "query": "%23UFCPittsburgh",
#     "promoted_content": null
#    },
#    {
#     "name": "#SoyVenezolanoY",
#     "url": "http://twitter.com/search?q=%23SoyVenezolanoY",
#     "tweet_volume": 10572,
#     "query": "%23SoyVenezolanoY",
#     "promoted_content": null
#    },
#    {
#     "name": "#HagamosConejoALaGuerra",
#     "url": "http://twitter.com/search?q=%23HagamosConejoALaGuerra",
#     "tweet_volume": null,
#     "query": "%23HagamosConejoALaGuerra",
#     "promoted_content": null
#    },
#    {
#     "name": "#LaMovidaEnEl13",
#     "url": "http://twitter.com/search?q=%23LaMovidaEnEl13",
#     "tweet_volume": null,
#     "query": "%23LaMovidaEnEl13",
#     "promoted_content": null
#    },
#    {
#     "name": "#Tecav\u00fczeSessizKalmayal\u0131m",
#     "url": "http://twitter.com/search?q=%23Tecav%C3%BCzeSessizKalmayal%C4%B1m",
#     "tweet_volume": null,
#     "query": "%23Tecav%C3%BCzeSessizKalmayal%C4%B1m",
#     "promoted_content": null
#    },
#    {
#     "name": "#gazebo",
#     "url": "http://twitter.com/search?q=%23gazebo",
#     "tweet_volume": null,
#     "query": "%23gazebo",
#     "promoted_content": null
#    },
#    {
#     "name": "#YGraciasAInternet",
#     "url": "http://twitter.com/search?q=%23YGraciasAInternet",
#     "tweet_volume": 12679,
#     "query": "%23YGraciasAInternet",
#     "promoted_content": null
#    },
#    {
#     "name": "#ChiringuitoMadrid",
#     "url": "http://twitter.com/search?q=%23ChiringuitoMadrid",
#     "tweet_volume": null,
#     "query": "%23ChiringuitoMadrid",
#     "promoted_content": null
#    },
#    {
#     "name": "#WWEFastlane",
#     "url": "http://twitter.com/search?q=%23WWEFastlane",
#     "tweet_volume": 41304,
#     "query": "%23WWEFastlane",
#     "promoted_content": null
#    },
#    {
#     "name": "#FuturoPop",
#     "url": "http://twitter.com/search?q=%23FuturoPop",
#     "tweet_volume": null,
#     "query": "%23FuturoPop",
#     "promoted_content": null
#    },
#    {
#     "name": "#RTE2ElectionSpecial",
#     "url": "http://twitter.com/search?q=%23RTE2ElectionSpecial",
#     "tweet_volume": null,
#     "query": "%23RTE2ElectionSpecial",
#     "promoted_content": null
#    },
#    {
#     "name": "#beyazfutbolkaragece",
#     "url": "http://twitter.com/search?q=%23beyazfutbolkaragece",
#     "tweet_volume": null,
#     "query": "%23beyazfutbolkaragece",
#     "promoted_content": null
#    },
#    {
#     "name": "#birhayatbirumut",
#     "url": "http://twitter.com/search?q=%23birhayatbirumut",
#     "tweet_volume": 13509,
#     "query": "%23birhayatbirumut",
#     "promoted_content": null
#    },
#    {
#     "name": "#CantadaNoFantastico",
#     "url": "http://twitter.com/search?q=%23CantadaNoFantastico",
#     "tweet_volume": null,
#     "query": "%23CantadaNoFantastico",
#     "promoted_content": null
#    },
#    {
#     "name": "#LeIene",
#     "url": "http://twitter.com/search?q=%23LeIene",
#     "tweet_volume": null,
#     "query": "%23LeIene",
#     "promoted_content": null
#    },
#    {
#     "name": "#StadiumSeries",
#     "url": "http://twitter.com/search?q=%23StadiumSeries",
#     "tweet_volume": 33549,
#     "query": "%23StadiumSeries",
#     "promoted_content": null
#    },
#    {
#     "name": "#ObjetivoGarz\u00f3n",
#     "url": "http://twitter.com/search?q=%23ObjetivoGarz%C3%B3n",
#     "tweet_volume": 14507,
#     "query": "%23ObjetivoGarz%C3%B3n",
#     "promoted_content": null
#    },
#    {
#     "name": "#\u0627\u0644\u0647\u0644\u0627\u0644_\u0641\u064a_\u0645\u062c\u0644\u0633_\u0642\u0646\u0627\u0647_\u0627\u0644\u0643\u0627\u0633",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D9%81%D9%8A_%D9%85%D8%AC%D9%84%D8%B3_%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D9%83%D8%A7%D8%B3",
#     "tweet_volume": 38742,
#     "query": "%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D9%81%D9%8A_%D9%85%D8%AC%D9%84%D8%B3_%D9%82%D9%86%D8%A7%D9%87_%D8%A7%D9%84%D9%83%D8%A7%D8%B3",
#     "promoted_content": null
#    },
#    {
#     "name": "#\u062a\u0642\u0648\u0644_\u0627\u0633\u0641\u0648\u062e\u0633_\u0644\u0645\u064a\u0646",
#     "url": "http://twitter.com/search?q=%23%D8%AA%D9%82%D9%88%D9%84_%D8%A7%D8%B3%D9%81%D9%88%D8%AE%D8%B3_%D9%84%D9%85%D9%8A%D9%86",
#     "tweet_volume": null,
#     "query": "%23%D8%AA%D9%82%D9%88%D9%84_%D8%A7%D8%B3%D9%81%D9%88%D8%AE%D8%B3_%D9%84%D9%85%D9%8A%D9%86",
#     "promoted_content": null
#    },
#    {
#     "name": "#\u0645\u062d\u0645\u062f_\u062f\u0627\u064a\u0631\u064a_\u0645\u0644\u064a\u0648\u0646_\u0645\u062a\u0627\u0628\u0639",
#     "url": "http://twitter.com/search?q=%23%D9%85%D8%AD%D9%85%D8%AF_%D8%AF%D8%A7%D9%8A%D8%B1%D9%8A_%D9%85%D9%84%D9%8A%D9%88%D9%86_%D9%85%D8%AA%D8%A7%D8%A8%D8%B9",
#     "tweet_volume": null,
#     "query": "%23%D9%85%D8%AD%D9%85%D8%AF_%D8%AF%D8%A7%D9%8A%D8%B1%D9%8A_%D9%85%D9%84%D9%8A%D9%88%D9%86_%D9%85%D8%AA%D8%A7%D8%A8%D8%B9",
#     "promoted_content": null
#    },
#    {
#     "name": "#USAvCAN",
#     "url": "http://twitter.com/search?q=%23USAvCAN",
#     "tweet_volume": 10814,
#     "query": "%23USAvCAN",
#     "promoted_content": null
#    },
#    {
#     "name": "#HocaefendiCanl\u0131Yay\u0131nda",
#     "url": "http://twitter.com/search?q=%23HocaefendiCanl%C4%B1Yay%C4%B1nda",
#     "tweet_volume": 39300,
#     "query": "%23HocaefendiCanl%C4%B1Yay%C4%B1nda",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-02-22T00:13:27Z",
#   "created_at": "2016-02-22T00:09:47Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "Anthony Davis",
#     "url": "http://twitter.com/search?q=%22Anthony+Davis%22",
#     "tweet_volume": 51423,
#     "query": "%22Anthony+Davis%22",
#     "promoted_content": null
#    },
#    {
#     "name": "#DAYTONA500",
#     "url": "http://twitter.com/search?q=%23DAYTONA500",
#     "tweet_volume": 360514,
#     "query": "%23DAYTONA500",
#     "promoted_content": null
#    },
#    {
#     "name": "Dion Waiters",
#     "url": "http://twitter.com/search?q=%22Dion+Waiters%22",
#     "tweet_volume": 13162,
#     "query": "%22Dion+Waiters%22",
#     "promoted_content": null
#    },
#    {
#     "name": "#StadiumSeries",
#     "url": "http://twitter.com/search?q=%23StadiumSeries",
#     "tweet_volume": 33367,
#     "query": "%23StadiumSeries",
#     "promoted_content": null
#    },
#    {
#     "name": "#UFCPittsburgh",
#     "url": "http://twitter.com/search?q=%23UFCPittsburgh",
#     "tweet_volume": 11839,
#     "query": "%23UFCPittsburgh",
#     "promoted_content": null
#    },
#    {
#     "name": "#USAvCAN",
#     "url": "http://twitter.com/search?q=%23USAvCAN",
#     "tweet_volume": 10620,
#     "query": "%23USAvCAN",
#     "promoted_content": null
#    },
#    {
#     "name": "#SupportToHarry",
#     "url": "http://twitter.com/search?q=%23SupportToHarry",
#     "tweet_volume": 156686,
#     "query": "%23SupportToHarry",
#     "promoted_content": null
#    },
#    {
#     "name": "Sam Pepper",
#     "url": "http://twitter.com/search?q=%22Sam+Pepper%22",
#     "tweet_volume": 23319,
#     "query": "%22Sam+Pepper%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Bubba Watson",
#     "url": "http://twitter.com/search?q=%22Bubba+Watson%22",
#     "tweet_volume": null,
#     "query": "%22Bubba+Watson%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Richard Jefferson",
#     "url": "http://twitter.com/search?q=%22Richard+Jefferson%22",
#     "tweet_volume": null,
#     "query": "%22Richard+Jefferson%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Drummond",
#     "url": "http://twitter.com/search?q=Drummond",
#     "tweet_volume": null,
#     "query": "Drummond",
#     "promoted_content": null
#    },
#    {
#     "name": "Zucker",
#     "url": "http://twitter.com/search?q=Zucker",
#     "tweet_volume": null,
#     "query": "Zucker",
#     "promoted_content": null
#    },
#    {
#     "name": "Steven Adams",
#     "url": "http://twitter.com/search?q=%22Steven+Adams%22",
#     "tweet_volume": null,
#     "query": "%22Steven+Adams%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Rozsival",
#     "url": "http://twitter.com/search?q=Rozsival",
#     "tweet_volume": null,
#     "query": "Rozsival",
#     "promoted_content": null
#    },
#    {
#     "name": "Megabus",
#     "url": "http://twitter.com/search?q=Megabus",
#     "tweet_volume": null,
#     "query": "Megabus",
#     "promoted_content": null
#    },
#    {
#     "name": "Pahrump",
#     "url": "http://twitter.com/search?q=Pahrump",
#     "tweet_volume": null,
#     "query": "Pahrump",
#     "promoted_content": null
#    },
#    {
#     "name": "SWEN LOVE JMO",
#     "url": "http://twitter.com/search?q=%22SWEN+LOVE+JMO%22",
#     "tweet_volume": null,
#     "query": "%22SWEN+LOVE+JMO%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Ibaka",
#     "url": "http://twitter.com/search?q=Ibaka",
#     "tweet_volume": null,
#     "query": "Ibaka",
#     "promoted_content": null
#    },
#    {
#     "name": "Kyle Anderson",
#     "url": "http://twitter.com/search?q=%22Kyle+Anderson%22",
#     "tweet_volume": null,
#     "query": "%22Kyle+Anderson%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Tancredi",
#     "url": "http://twitter.com/search?q=Tancredi",
#     "tweet_volume": null,
#     "query": "Tancredi",
#     "promoted_content": null
#    },
#    {
#     "name": "Mark Sertich",
#     "url": "http://twitter.com/search?q=%22Mark+Sertich%22",
#     "tweet_volume": null,
#     "query": "%22Mark+Sertich%22",
#     "promoted_content": null
#    },
#    {
#     "name": "Hubie Brown",
#     "url": "http://twitter.com/search?q=%22Hubie+Brown%22",
#     "tweet_volume": null,
#     "query": "%22Hubie+Brown%22",
#     "promoted_content": null
#    },
#    {
#     "name": "#YouStartedItWhen",
#     "url": "http://twitter.com/search?q=%23YouStartedItWhen",
#     "tweet_volume": null,
#     "query": "%23YouStartedItWhen",
#     "promoted_content": null
#    },
#    {
#     "name": "#WWEFastlane",
#     "url": "http://twitter.com/search?q=%23WWEFastlane",
#     "tweet_volume": 38190,
#     "query": "%23WWEFastlane",
#     "promoted_content": null
#    },
#    {
#     "name": "#SundayFunday",
#     "url": "http://twitter.com/search?q=%23SundayFunday",
#     "tweet_volume": 25262,
#     "query": "%23SundayFunday",
#     "promoted_content": null
#    },
#    {
#     "name": "#PhotographCover",
#     "url": "http://twitter.com/search?q=%23PhotographCover",
#     "tweet_volume": 28887,
#     "query": "%23PhotographCover",
#     "promoted_content": null
#    },
#    {
#     "name": "#FakeSocialMediaFacts",
#     "url": "http://twitter.com/search?q=%23FakeSocialMediaFacts",
#     "tweet_volume": null,
#     "query": "%23FakeSocialMediaFacts",
#     "promoted_content": null
#    },
#    {
#     "name": "#AskGillianA",
#     "url": "http://twitter.com/search?q=%23AskGillianA",
#     "tweet_volume": 35493,
#     "query": "%23AskGillianA",
#     "promoted_content": null
#    },
#    {
#     "name": "#UnwantedEbayItems",
#     "url": "http://twitter.com/search?q=%23UnwantedEbayItems",
#     "tweet_volume": null,
#     "query": "%23UnwantedEbayItems",
#     "promoted_content": null
#    },
#    {
#     "name": "#FearTheBrow",
#     "url": "http://twitter.com/search?q=%23FearTheBrow",
#     "tweet_volume": null,
#     "query": "%23FearTheBrow",
#     "promoted_content": null
#    },
#    {
#     "name": "#Disneyland60",
#     "url": "http://twitter.com/search?q=%23Disneyland60",
#     "tweet_volume": null,
#     "query": "%23Disneyland60",
#     "promoted_content": null
#    },
#    {
#     "name": "#JoyrideWorldTour",
#     "url": "http://twitter.com/search?q=%23JoyrideWorldTour",
#     "tweet_volume": null,
#     "query": "%23JoyrideWorldTour",
#     "promoted_content": null
#    },
#    {
#     "name": "#BEAST6",
#     "url": "http://twitter.com/search?q=%23BEAST6",
#     "tweet_volume": null,
#     "query": "%23BEAST6",
#     "promoted_content": null
#    },
#    {
#     "name": "#TheNextGalaxy",
#     "url": "http://twitter.com/search?q=%23TheNextGalaxy",
#     "tweet_volume": 84189,
#     "query": "%23TheNextGalaxy",
#     "promoted_content": null
#    },
#    {
#     "name": "#OKCvsCLE",
#     "url": "http://twitter.com/search?q=%23OKCvsCLE",
#     "tweet_volume": null,
#     "query": "%23OKCvsCLE",
#     "promoted_content": null
#    },
#    {
#     "name": "#StripperNameFails",
#     "url": "http://twitter.com/search?q=%23StripperNameFails",
#     "tweet_volume": null,
#     "query": "%23StripperNameFails",
#     "promoted_content": null
#    },
#    {
#     "name": "#ibminterconect",
#     "url": "http://twitter.com/search?q=%23ibminterconect",
#     "tweet_volume": null,
#     "query": "%23ibminterconect",
#     "promoted_content": null
#    },
#    {
#     "name": "#EXOluXioninNY",
#     "url": "http://twitter.com/search?q=%23EXOluXioninNY",
#     "tweet_volume": 12316,
#     "query": "%23EXOluXioninNY",
#     "promoted_content": null
#    },
#    {
#     "name": "#THON2016",
#     "url": "http://twitter.com/search?q=%23THON2016",
#     "tweet_volume": null,
#     "query": "%23THON2016",
#     "promoted_content": null
#    },
#    {
#     "name": "#drinkitnow",
#     "url": "http://twitter.com/search?q=%23drinkitnow",
#     "tweet_volume": null,
#     "query": "%23drinkitnow",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-02-22T00:13:28Z",
#   "created_at": "2016-02-22T00:04:37Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#WWEFastlane', 'Anthony Davis', '#SupportToHarry', '#StadiumSeries', 'Dion Waiters', '#DAYTONA500', '#UFCPittsburgh', '#USAvCAN'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
#from urllib import unquote

from urllib.parse import unquote
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#MentionSomeoneImportantForYou' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 1
# {
#  "metadata": {
#   "result_type": "recent",
#   "iso_language_code": "in"
#  },
#  "id_str": "700344257723265025",
#  "in_reply_to_status_id": null,
#  "geo": null,
#  "truncated": false,
#  "in_reply_to_screen_name": null,
#  "contributors": null,
#  "favorited": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MentionSomeoneImportantForYou",
#     "indices": [
#      52,
#      82
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "name": "bie\uc8fc",
#     "indices": [
#      3,
#      12
#     ],
#     "screen_name": "larvarhj",
#     "id_str": "750178340",
#     "id": 750178340
#    }
#   ],
#   "urls": []
#  },
#  "retweet_count": 1,
#  "in_reply_to_status_id_str": null,
#  "retweeted_status": {
#   "metadata": {
#    "result_type": "recent",
#    "iso_language_code": "in"
#   },
#   "id_str": "317107300835934209",
#   "in_reply_to_status_id": null,
#   "geo": null,
#   "truncated": false,
#   "in_reply_to_screen_name": null,
#   "contributors": null,
#   "favorited": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MentionSomeoneImportantForYou",
#      "indices": [
#       38,
#       68
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": []
#   },
#   "retweet_count": 1,
#   "in_reply_to_status_id_str": null,
#   "created_at": "Thu Mar 28 02:54:06 +0000 2013",
#   "retweeted": false,
#   "in_reply_to_user_id": null,
#   "coordinates": null,
#   "user": {
#    "geo_enabled": false,
#    "notifications": false,
#    "is_translation_enabled": false,
#    "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/451203381369905154/UNunkMJF.jpeg",
#    "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/451203381369905154/UNunkMJF.jpeg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/656949537697755136/1xRV2UQN_normal.jpg",
#    "has_extended_profile": false,
#    "following": false,
#    "statuses_count": 46619,
#    "contributors_enabled": false,
#    "profile_text_color": "0C3E53",
#    "created_at": "Fri Aug 10 22:35:28 +0000 2012",
#    "verified": false,
#    "id_str": "750178340",
#    "is_translator": false,
#    "location": "",
#    "time_zone": "Beijing",
#    "description": "(91') ulzzang roleplayer's ryu hyeju.",
#    "url": "http://t.co/LhxEsdllqf",
#    "listed_count": 7,
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "http://t.co/LhxEsdllqf",
#        "expanded_url": "http://bieju.co.kr",
#        "display_url": "bieju.co.kr",
#        "indices": [
#         0,
#         22
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "favourites_count": 1765,
#    "utc_offset": 28800,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/750178340/1436990071",
#    "default_profile_image": false,
#    "default_profile": false,
#    "profile_use_background_image": true,
#    "followers_count": 656,
#    "profile_link_color": "FCA9A9",
#    "profile_background_color": "BADFCD",
#    "id": 750178340,
#    "profile_sidebar_border_color": "FFFFFF",
#    "protected": false,
#    "screen_name": "larvarhj",
#    "friends_count": 31,
#    "name": "bie\uc8fc",
#    "profile_background_tile": true,
#    "profile_sidebar_fill_color": "FFF7CC",
#    "follow_request_sent": false,
#    "lang": "en",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/656949537697755136/1xRV2UQN_normal.jpg"
#   },
#   "id": 317107300835934209,
#   "source": "<a href=\"http://www.tweetcaster.com\" rel=\"nofollow\">TweetCaster for Android</a>",
#   "place": null,
#   "in_reply_to_user_id_str": null,
#   "favorite_count": 1,
#   "text": "ejiee jieee buahaha RT @VIN_DaniTara: #MentionSomeoneImportantForYou @SOOhyun_HG :$",
#   "is_quote_status": false,
#   "lang": "in"
#  },
#  "created_at": "Thu Feb 18 15:40:57 +0000 2016",
#  "retweeted": false,
#  "in_reply_to_user_id": null,
#  "coordinates": null,
#  "user": {
#   "geo_enabled": false,
#   "notifications": false,
#   "is_translation_enabled": false,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/680118214475399168/PpE5gTjN_normal.jpg",
#   "has_extended_profile": true,
#   "following": false,
#   "statuses_count": 54804,
#   "contributors_enabled": false,
#   "profile_text_color": "666666",
#   "created_at": "Sun Nov 25 12:45:43 +0000 2012",
#   "verified": false,
#   "id_str": "969968298",
#   "is_translator": false,
#   "location": "Bali, Indonesia",
#   "time_zone": "Urumqi",
#   "description": "25+] i dnt nid a man",
#   "url": null,
#   "listed_count": 1,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "favourites_count": 772,
#   "utc_offset": 21600,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/969968298/1450987791",
#   "default_profile_image": false,
#   "default_profile": false,
#   "profile_use_background_image": true,
#   "followers_count": 5187,
#   "profile_link_color": "2FC2EF",
#   "profile_background_color": "1A1B1F",
#   "id": 969968298,
#   "profile_sidebar_border_color": "181A1E",
#   "protected": false,
#   "screen_name": "ciciborahh",
#   "friends_count": 4147,
#   "name": "anyak",
#   "profile_background_tile": false,
#   "profile_sidebar_fill_color": "252429",
#   "follow_request_sent": false,
#   "lang": "en",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/680118214475399168/PpE5gTjN_normal.jpg"
#  },
#  "id": 700344257723265025,
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "place": null,
#  "in_reply_to_user_id_str": null,
#  "favorite_count": 0,
#  "text": "RT @larvarhj: ejiee jieee buahaha RT @VIN_DaniTara: #MentionSomeoneImportantForYou @SOOhyun_HG :$",
#  "is_quote_status": false,
#  "lang": "in"
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print (t['retweet_count'])
print (t['retweeted_status'])

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 23
# {'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'contributors': None, 'in_reply_to_status_id': None, 'favorite_count': 0, 'truncated': False, 'in_reply_to_screen_name': None, 'id_str': '316944833233186816', 'favorited': False, 'entities': {'hashtags': [{'text': 'MentionSomeoneImportantForYou', 'indices': [0, 30]}], 'user_mentions': [], 'urls': []}, 'retweet_count': 23, 'in_reply_to_status_id_str': None, 'created_at': 'Wed Mar 27 16:08:31 +0000 2013', 'retweeted': False, 'in_reply_to_user_id': None, 'coordinates': None, 'user': {'profile_text_color': '3C3940', 'notifications': None, 'url': 'http://t.co/yRX89YM4J0', 'profile_background_image_url_https': 'https://si0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'profile_background_image_url': 'http://a0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'profile_image_url_https': 'https://si0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', 'following': None, 'statuses_count': 16691, 'contributors_enabled': False, 'geo_enabled': True, 'verified': False, 'id_str': '56259379', 'is_translator': False, 'location': '', 'time_zone': 'Eastern Time (US & Canada)', 'created_at': 'Mon Jul 13 02:18:25 +0000 2009', 'description': '#TheseAreTheWordsISaid LP', 'default_profile_image': False, 'listed_count': 64, 'profile_link_color': '91785A', 'favourites_count': 6142, 'utc_offset': -18000, 'profile_banner_url': 'https://si0.twimg.com/profile_banners/56259379/1363388572', 'entities': {'url': {'urls': [{'url': 'http://t.co/yRX89YM4J0', 'expanded_url': 'http://www.datpiff.com/mixtapes-detail.php?id=470069', 'display_url': 'datpiff.com/mixtapes-detai…', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'default_profile': False, 'profile_use_background_image': True, 'followers_count': 105041, 'profile_background_color': '000000', 'id': 56259379, 'profile_sidebar_border_color': '000000', 'protected': False, 'screen_name': 'hassanmusician', 'friends_count': 59615, 'name': 'Download the NEW LP!', 'profile_background_tile': False, 'profile_sidebar_fill_color': '95E8EC', 'follow_request_sent': None, 'lang': 'en', 'profile_image_url': 'http://a0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg'}, 'id': 316944833233186816, 'source': 'web', 'place': None, 'in_reply_to_user_id_str': None, 'geo': None, 'text': '#MentionSomeoneImportantForYou God.', 'lang': 'en'}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1))
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\ud83d\udc4d",
#  "#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.",
#  "RT @hassanmusician: #MentionSomeoneImportantForYou God.",
#  "#MentionSomeoneImportantForYou @Louis_Tomlinson",
#  "#MentionSomeoneImportantForYou @Delta_Universe"
# ]
# [
#  "KathleenMariee_",
#  "AhhlicksCruise",
#  "itsravennn_cx",
#  "kandykisses_13",
#  "BMOLOGY"
# ]
# [
#  "MentionSomeOneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou"
# ]
# [
#  "\u201c@KathleenMariee_:",
#  "#MentionSomeOneImportantForYou",
#  "@AhhlicksCruise",
#  ",",
#  "@itsravennn_cx"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10])
# Out:
# [('#MentionSomeoneImportantForYou', 92), ('RT', 34), ('my', 10), (',', 6), ('@justinbieber', 6), ('&lt;3', 6), ('My', 5), ('I', 4), ('and', 4), ('#mentionsomeoneimportantforyou', 3)]
# [('justinbieber', 6), ('Cavillafuerte', 2), ('Kid_Charliej', 2), ('KittyFitzimors', 1), ('ummey_imnida', 1), ('hassanmusician', 1), ('luffy093', 1), ('heyitsadila', 1), ('ohohbree', 1), ('GR_78', 1)]
# [('MentionSomeoneImportantForYou', 94), ('mentionsomeoneimportantforyou', 3), ('MyHeart', 1), ('NoHomo', 1), ('Love', 1), ('bebesito', 1), ('MentionSomeOneImportantForYou', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:15] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +--------------------------------+-------+
# | Word                           | Count |
# +--------------------------------+-------+
# | #MentionSomeoneImportantForYou |    92 |
# | RT                             |    34 |
# | my                             |    10 |
# | ,                              |     6 |
# | @justinbieber                  |     6 |
# | &lt;3                          |     6 |
# | My                             |     5 |
# | I                              |     4 |
# | and                            |     4 |
# | #mentionsomeoneimportantforyou |     3 |
# | love                           |     3 |
# | te                             |     3 |
# | me                             |     3 |
# | just                           |     3 |
# | con                            |     2 |
# +--------------------------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | justinbieber   |     6 |
# | Cavillafuerte  |     2 |
# | Kid_Charliej   |     2 |
# | KittyFitzimors |     1 |
# | ummey_imnida   |     1 |
# | hassanmusician |     1 |
# | luffy093       |     1 |
# | heyitsadila    |     1 |
# | ohohbree       |     1 |
# | GR_78          |     1 |
# | WubbyThoxD     |     1 |
# | _zizo96        |     1 |
# | ErickPaz96     |     1 |
# | IsaacCanto1    |     1 |
# | KHarler        |     1 |
# +----------------+-------+
# +-------------------------------+-------+
# | Hashtag                       | Count |
# +-------------------------------+-------+
# | MentionSomeoneImportantForYou |    94 |
# | mentionsomeoneimportantforyou |     3 |
# | MyHeart                       |     1 |
# | NoHomo                        |     1 |
# | Love                          |     1 |
# | bebesito                      |     1 |
# | MentionSomeOneImportantForYou |     1 |
# +-------------------------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print (lexical_diversity(words))
print (lexical_diversity(screen_names))
print (lexical_diversity(hashtags))
print (average_words(status_texts))
# Out:
# 0.6761061946902654
# 0.9554140127388535
# 0.06862745098039216
# 5.76530612245

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status.keys()
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:10] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 23    | hassanmusician | RT @hassanmusician: #MentionSomeoneImportantForYou |
# |       |                | God.                                               |
# | 21    | HSweethearts   | RT @HSweethearts: #MentionSomeoneImportantForYou   |
# |       |                | my high school sweetheart ❤💋                       |
# | 15    | LosAlejandro_  | RT @LosAlejandro_: ¿Nadie te menciono en           |
# |       |                | "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJA |
# |       |                | JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...  |
# | 9     | SCOTTSUMME     | RT @SCOTTSUMME: #MentionSomeoneImportantForYou My  |
# |       |                | Mum. Shes loving, caring, strong, all in one. I    |
# |       |                | love her so much ❤❤❤❤                              |
# | 7     | degrassihaha   | RT @degrassihaha: #MentionSomeoneImportantForYou I |
# |       |                | can't put every Degrassi cast member, crew member, |
# |       |                | and writer in just one tweet....                   |
# | 6     | NurIzzaty_     | RT @NurIzzaty_: #MentionSomeoneImportantForYou     |
# |       |                | @SharifahAnnisa @Faaaarz @gyunana95 @WeyhBudak     |
# |       |                | @WeyhDayah @WeyhCinee @ummey_imnida :'*            |
# | 5     | _Phoenixer     | RT @_Phoenixer: #MentionSomeoneImportantForYou     |
# |       |                | @__iHk  @_Swordsgirl @iPinoochio @UriMyMy          |
# |       |                | @_zizo96 @iKureiji @GR_78                          |
# | 3     | _SitiAdly      | RT @_SitiAdly: #MentionSomeoneImportantForYou      |
# |       |                | @SaraaaaahN_ ,@heyitsadila ,@fareenawr             |
# |       |                | @farezahbieber94 @HLAVEGAS @rsfiena @AdlySK        |
# |       |                | @FienaS ...                                        |
# | 3     | KittyFitzimors | RT @KittyFitzimors: #mentionsomeoneimportantforyou |
# |       |                | my chemical romance                                |
# |       |                |                                                    |
# |       |                | My life savers                                     |
# | 2     | danny_dessen   | RT @danny_dessen: #MentionSomeoneImportantForYou   |
# |       |                | @hsigurdson @AgussDe1D @KHarler @iHoransTeam       |
# +-------+----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print ([r['user']['screen_name'] for r in _retweets])
# Out:
# ['melissacaaag', 'jyeee', 'Ceejaynatics', 'Majendalove', 'ikaayyy_', 'RafaellaaaMae', 'LoveKyana18', 'iiaamcamillee', 'kidamgos', 'shangxshang', 'asdfghjbl', 'Papagars__']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    # plt.plot([1,2,3,4])
    # plt.ylabel('some numbers')
    # plt.show()
    
    c = Counter(data)
   
    #plt.plot([value for value in c.values()])
    plt.hist([value for value in c.values()])
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print (counts)
# Out:
# [23, 1, 21, 1, 5, 2, 2, 2, 3, 1, 1, 1, 1, 9, 1, 1, 1, 15, 1, 1, 1, 2, 1, 1, 7, 6, 1, 3, 1, 1, 1, 1, 1]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(log(counts))
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print(log(counts))
# Out:
# [ 3.13549422  0.          3.04452244  0.          1.60943791  0.69314718
#   0.69314718  0.69314718  1.09861229  0.          0.          0.          0.
#   2.19722458  0.          0.          0.          2.7080502   0.          0.
#   0.          0.69314718  0.          0.          1.94591015  1.79175947
#   0.          1.09861229  0.          0.          0.          0.          0.        ]
